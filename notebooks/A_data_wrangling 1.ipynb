# %% [markdown]
# # A. Data Wrangling

# %% [markdown]
# # 1. Purpose of This Data Science Project

# %% [markdown]
# The purpose of this data science project is to develop a pricing model for rents listed on rental postings. Property owners would benefit from listing their property at an appropriate price and in line with their position in the market. Owners would also benefit from insights to high-value versus low-value features.

# %% [markdown]
# # 2. Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
pd.options.display.max_columns = None
import missingno as msno
import pandas_profiling
from pandas_profiling.utils.cache import cache_file
from collections import defaultdict
from datetime import datetime
from fuzzywuzzy import process, fuzz
import itertools
# Out:
# C:\Users\zebin\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# # 3. Objectives of This Notebook

# %% [markdown]
# - To determine if the data we have could be use to develop a pricing model
#     - Verify that there is an appropriate target feature
#     - Verify that there are potentially useful features
# - Verify that there are not fundamental issues with the data

# %% [markdown]
# # 4. Loading Data

# %%
immo_data= pd.read_csv('../data/raw/immo_data.csv')

# %%
rentals = immo_data.copy()

# %%
rentals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268850 entries, 0 to 268849
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   regio1                    268850 non-null  object
#  1   serviceCharge             261941 non-null  float64
#  2   heatingType               223994 non-null  object
#  3   telekomTvOffer            236231 non-null  object
#  4   telekomHybridUploadSpeed  45020 non-null   float64
#  5   newlyConst                268850 non-null  bool
#  6   balcony                   268850 non-null  bool
#  7   picturecount              268850 non-null  int64
#  8   pricetrend                267018 non-null  float64
#  9   telekomUploadSpeed        235492 non-null  float64
#  10  totalRent                 228333 non-null  float64
#  11  yearConstructed           211805 non-null  float64
#  12  scoutId                   268850 non-null  int64
#  13  noParkSpaces              93052 non-null   float64
#  14  firingTypes               211886 non-null  object
#  15  hasKitchen                268850 non-null  bool
#  16  geo_bln                   268850 non-null  object
#  17  cellar                    268850 non-null  bool
#  18  yearConstructedRange      211805 non-null  float64
#  19  baseRent                  268850 non-null  float64
#  20  houseNumber               197832 non-null  object
#  21  livingSpace               268850 non-null  float64
#  22  geo_krs                   268850 non-null  object
#  23  condition                 200361 non-null  object
#  24  interiorQual              156185 non-null  object
#  25  petsAllowed               154277 non-null  object
#  26  street                    268850 non-null  object
#  27  streetPlain               197837 non-null  object
#  28  lift                      268850 non-null  bool
#  29  baseRentRange             268850 non-null  int64
#  30  typeOfFlat                232236 non-null  object
#  31  geo_plz                   268850 non-null  int64
#  32  noRooms                   268850 non-null  float64
#  33  thermalChar               162344 non-null  float64
#  34  floor                     217541 non-null  float64
#  35  numberOfFloors            171118 non-null  float64
#  36  noRoomsRange              268850 non-null  int64
#  37  garden                    268850 non-null  bool
#  38  livingSpaceRange          268850 non-null  int64
#  39  regio2                    268850 non-null  object
#  40  regio3                    268850 non-null  object
#  41  description               249103 non-null  object
#  42  facilities                215926 non-null  object
#  43  heatingCosts              85518 non-null   float64
#  44  energyEfficiencyClass     77787 non-null   object
#  45  lastRefurbish             80711 non-null   float64
#  46  electricityBasePrice      46846 non-null   float64
#  47  electricityKwhPrice       46846 non-null   float64
#  48  date                      268850 non-null  object
# dtypes: bool(6), float64(18), int64(6), object(19)
# memory usage: 89.7+ MB

# %%
rentals.head()
# Out:
#                 regio1  serviceCharge                     heatingType  \
# 0  Nordrhein_Westfalen         245.00                 central_heating
# 1      Rheinland_Pfalz         134.00  self_contained_central_heating
# 2              Sachsen         255.00                   floor_heating
# 3              Sachsen          58.15                district_heating
# 4               Bremen         138.00  self_contained_central_heating
#
#   telekomTvOffer  telekomHybridUploadSpeed  newlyConst  balcony  picturecount  \
# 0  ONE_YEAR_FREE                       NaN       False    False             6
# 1  ONE_YEAR_FREE                       NaN       False     True             8
# 2  ONE_YEAR_FREE                      10.0        True     True             8
# 3  ONE_YEAR_FREE                       NaN       False     True             9
# 4            NaN                       NaN       False     True            19
#
#    pricetrend  telekomUploadSpeed  totalRent  yearConstructed    scoutId  \
# 0        4.62                10.0      840.0           1965.0   96107057
# 1        3.47                10.0        NaN           1871.0  111378734
# 2        2.72                 2.4     1300.0           2019.0  113147523
# 3        1.53                40.0        NaN           1964.0  108890903
# 4        2.46                 NaN      903.0           1950.0  114751222
#
#    noParkSpaces       firingTypes  hasKitchen              geo_bln  cellar  \
# 0           1.0               oil       False  Nordrhein_Westfalen    True
# 1           2.0               gas       False      Rheinland_Pfalz   False
# 2           1.0               NaN       False              Sachsen    True
# 3           NaN  district_heating       False              Sachsen   False
# 4           NaN               gas       False               Bremen   False
#
#    yearConstructedRange  baseRent houseNumber  livingSpace  \
# 0                   2.0     595.0         244        86.00
# 1                   1.0     800.0         NaN        89.00
# 2                   9.0     965.0           4        83.80
# 3                   2.0     343.0          35        58.15
# 4                   1.0     765.0          10        84.97
#
#                geo_krs       condition   interiorQual petsAllowed  \
# 0             Dortmund       well_kept         normal         NaN
# 1    Rhein_Pfalz_Kreis     refurbished         normal          no
# 2              Dresden  first_time_use  sophisticated         NaN
# 3  Mittelsachsen_Kreis             NaN            NaN         NaN
# 4               Bremen     refurbished            NaN         NaN
#
#                         street                  streetPlain   lift  \
# 0   Sch&uuml;ruferstra&szlig;e              Schüruferstraße  False
# 1               no_information                          NaN  False
# 2                    Turnerweg                    Turnerweg   True
# 3  Gl&uuml;ck-Auf-Stra&szlig;e             Glück-Auf-Straße  False
# 4  Hermann-Henrich-Meier-Allee  Hermann-Henrich-Meier-Allee  False
#
#    baseRentRange    typeOfFlat  geo_plz  noRooms  thermalChar  floor  \
# 0              4  ground_floor    44269      4.0        181.4    1.0
# 1              5  ground_floor    67459      3.0          NaN    NaN
# 2              6     apartment     1097      3.0          NaN    3.0
# 3              2         other     9599      3.0         86.0    3.0
# 4              5     apartment    28213      3.0        188.9    1.0
#
#    numberOfFloors  noRoomsRange  garden  livingSpaceRange  \
# 0             3.0             4    True                 4
# 1             NaN             3   False                 4
# 2             4.0             3   False                 4
# 3             NaN             3   False                 2
# 4             NaN             3   False                 4
#
#                 regio2                      regio3  \
# 0             Dortmund                     Schüren
# 1    Rhein_Pfalz_Kreis              Böhl_Iggelheim
# 2              Dresden  Äußere_Neustadt_Antonstadt
# 3  Mittelsachsen_Kreis                    Freiberg
# 4               Bremen           Neu_Schwachhausen
#
#                                          description  \
# 0  Die ebenerdig zu erreichende Erdgeschosswohnun...
# 1  Alles neu macht der Mai – so kann es auch für ...
# 2  Der Neubau entsteht im Herzen der Dresdner Neu...
# 3  Abseits von Lärm und Abgasen in Ihre neue Wohn...
# 4  Es handelt sich hier um ein saniertes Mehrfami...
#
#                                           facilities  heatingCosts  \
# 0  Die Wohnung ist mit Laminat ausgelegt. Das Bad...           NaN
# 1                                                NaN           NaN
# 2  * 9 m² Balkon\n* Bad mit bodengleicher Dusche,...           NaN
# 3                                                NaN         87.23
# 4  Diese Wohnung wurde neu saniert und ist wie fo...           NaN
#
#   energyEfficiencyClass  lastRefurbish  electricityBasePrice  \
# 0                   NaN            NaN                   NaN
# 1                   NaN         2019.0                   NaN
# 2                   NaN            NaN                   NaN
# 3                   NaN            NaN                   NaN
# 4                   NaN            NaN                   NaN
#
#    electricityKwhPrice   date
# 0                  NaN  May19
# 1                  NaN  May19
# 2                  NaN  Oct19
# 3                  NaN  May19
# 4                  NaN  Feb20

# %% [markdown]
# # 5. Explore Data

# %% [markdown]
# ## 5.1 Datetime Features

# %% [markdown]
# - We observed that certain features were dates. We will convert these features to a datetime format

# %%
#Convert yearConstructed, lastRefurbish and date to datetime
rentals.yearConstructed = pd.to_datetime(rentals.yearConstructed, format = '%Y', errors = 'coerce')
rentals.lastRefurbish = pd.to_datetime(rentals.lastRefurbish, format = '%Y', errors = 'coerce')
rentals.date = pd.to_datetime(rentals.date, format = '%b%y')

# %%
#Verify datetime features
rentals.select_dtypes(include=[np.datetime64]).head(3)
# Out:
#   yearConstructed lastRefurbish       date
# 0      1965-01-01           NaT 2019-05-01
# 1      1871-01-01    2019-01-01 2019-05-01
# 2      2019-01-01           NaT 2019-10-01

# %% [markdown]
# ## 5.2 Crossfield Validation of Price-related Features

# %% [markdown]
# - Data owner noted that totalRent was the sum of baseRent, serviceCharge and heatingCosts. Let us review these features to determine which rows adhere to this formula

# %%
#Create new crossfield validation features and specify variable with price and crossfield validation features
rentals['crossfield_service'] = rentals.baseRent + rentals.serviceCharge
rentals['crossfield_heating'] = rentals.baseRent + rentals.heatingCosts
rentals['crossfield_all'] = rentals.baseRent + rentals.serviceCharge + rentals.heatingCosts
crossfields = ['baseRent','serviceCharge', 'heatingCosts','crossfield_service', \
               'crossfield_heating','crossfield_all', 'totalRent']
rentals[crossfields].sample(10)
# Out:
#         baseRent  serviceCharge  heatingCosts  crossfield_service  \
# 22482     568.76         202.00         84.00              770.76
# 142022    360.00          90.00           NaN              450.00
# 89090     555.00         195.00           NaN              750.00
# 230180    171.20          76.13         28.55              247.33
# 231840    550.00         170.00           NaN              720.00
# 211660    520.00         115.00           NaN              635.00
# 167330    200.00            NaN           NaN                 NaN
# 7167      296.62          77.50         56.00              374.12
# 195417    950.00         250.00           NaN             1200.00
# 238288   1065.47         110.00        170.00             1175.47
#
#         crossfield_heating  crossfield_all  totalRent
# 22482               652.76          854.76     854.76
# 142022                 NaN             NaN     450.00
# 89090                  NaN             NaN     750.00
# 230180              199.75          275.88     247.33
# 231840                 NaN             NaN     772.00
# 211660                 NaN             NaN     635.00
# 167330                 NaN             NaN     250.00
# 7167                352.62          430.12     430.12
# 195417                 NaN             NaN    1200.00
# 238288             1235.47         1345.47    1345.47

# %%
'''Use np.select to allocate the value of a crossfield feature to a new feature if the 
    crossfield has the same value as the total rent'''
conditions = [rentals.totalRent == rentals.baseRent, rentals.totalRent == rentals.crossfield_service, \
              rentals.totalRent == rentals.crossfield_heating, rentals.totalRent == rentals.crossfield_all]
choices = [rentals.baseRent, rentals.crossfield_service, rentals.crossfield_heating, rentals.crossfield_all]
rentals['cf_validation'] = np.select(conditions, choices, default = np.nan)

# %%
#Specify a variable to display partial dataframe with crossfield and price-related information
valCrossfields = ['baseRent','serviceCharge', 'heatingCosts','crossfield_service', \
               'crossfield_heating','crossfield_all','cf_validation', 'totalRent']

# %%
#View new cf_validation variable with non-null entries
rentals.loc[rentals.cf_validation.notnull(), valCrossfields].head()
# Out:
#    baseRent  serviceCharge  heatingCosts  crossfield_service  \
# 0    595.00          245.0           NaN              840.00
# 4    765.00          138.0           NaN              903.00
# 6    310.00           70.0           NaN              380.00
# 7    452.25           88.0          44.0              540.25
# 8    580.00          110.0           NaN              690.00
#
#    crossfield_heating  crossfield_all  cf_validation  totalRent
# 0                 NaN             NaN         840.00     840.00
# 4                 NaN             NaN         903.00     903.00
# 6                 NaN             NaN         380.00     380.00
# 7              496.25          584.25         584.25     584.25
# 8                 NaN             NaN         690.00     690.00

# %%
#Determine number of listings without a cf_validation entry
rentals.cf_validation.isnull().sum()
# Out:
# 67533

# %%
#View null cf_valiation entries where totalRent is non-null
rentals.loc[rentals.cf_validation.isnull() & rentals.totalRent.notnull(), valCrossfields]. \
            sort_values(by = 'totalRent', ascending = False).head(20)
# Out:
#         baseRent  serviceCharge  heatingCosts  crossfield_service  \
# 239533   1325.00         250.00           NaN             1575.00
# 109047    950.00         200.00           NaN             1150.00
# 79903     350.00         135.00           NaN              485.00
# 23490     820.00         260.00           NaN             1080.00
# 197378    487.51         159.00           NaN              646.51
# 16832     460.29         171.75           NaN              632.04
# 97927     427.70          50.00          38.0              477.70
# 240954    266.00         110.00           NaN              376.00
# 50706     184.00          11.19           NaN              195.19
# 57237   13000.00        1550.00           NaN            14550.00
# 209250   1050.00         180.00          70.0             1230.00
# 38143   10500.00        2000.00           NaN            12500.00
# 255251   1050.00         200.00         100.0             1250.00
# 65562    9500.00         760.00           NaN            10260.00
# 214772   6580.00         780.00           NaN             7360.00
# 9055     8700.00         405.00         245.0             9105.00
# 101948   6109.00         690.00           NaN             6799.00
# 201485   5680.00        1665.00           NaN             7345.00
# 204189   5800.00        1739.56           NaN             7539.56
# 29245    4910.00        1700.00           NaN             6610.00
#
#         crossfield_heating  crossfield_all  cf_validation    totalRent
# 239533                 NaN             NaN            NaN  15751535.00
# 109047                 NaN             NaN            NaN   1150900.00
# 79903                  NaN             NaN            NaN    485350.00
# 23490                  NaN             NaN            NaN    108000.00
# 197378                 NaN             NaN            NaN     64651.00
# 16832                  NaN             NaN            NaN     63204.00
# 97927                465.7           515.7            NaN     51570.00
# 240954                 NaN             NaN            NaN     37600.00
# 50706                  NaN             NaN            NaN     19519.00
# 57237                  NaN             NaN            NaN     15000.00
# 209250              1120.0          1300.0            NaN     13500.00
# 38143                  NaN             NaN            NaN     11900.00
# 255251              1150.0          1350.0            NaN     11250.00
# 65562                  NaN             NaN            NaN      9774.00
# 214772                 NaN             NaN            NaN      8780.00
# 9055                8945.0          9350.0            NaN      8706.00
# 101948                 NaN             NaN            NaN      8124.00
# 201485                 NaN             NaN            NaN      7745.00
# 204189                 NaN             NaN            NaN      7539.56
# 29245                  NaN             NaN            NaN      7000.00

# %% [markdown]
# - We note that the top 9 values for total rent are mistakes having to do with misplaced decimal points. We will replace them with their appropriate crossfield validation entries.

# %%
#Define indexes to change
indexes = [239533, 109047, 79903, 23490, 197378, 16832, 97927, 240954, 50706]

# %%
#View indexes
rentals.loc[indexes, valCrossfields]
# Out:
#         baseRent  serviceCharge  heatingCosts  crossfield_service  \
# 239533   1325.00         250.00           NaN             1575.00
# 109047    950.00         200.00           NaN             1150.00
# 79903     350.00         135.00           NaN              485.00
# 23490     820.00         260.00           NaN             1080.00
# 197378    487.51         159.00           NaN              646.51
# 16832     460.29         171.75           NaN              632.04
# 97927     427.70          50.00          38.0              477.70
# 240954    266.00         110.00           NaN              376.00
# 50706     184.00          11.19           NaN              195.19
#
#         crossfield_heating  crossfield_all  cf_validation   totalRent
# 239533                 NaN             NaN            NaN  15751535.0
# 109047                 NaN             NaN            NaN   1150900.0
# 79903                  NaN             NaN            NaN    485350.0
# 23490                  NaN             NaN            NaN    108000.0
# 197378                 NaN             NaN            NaN     64651.0
# 16832                  NaN             NaN            NaN     63204.0
# 97927                465.7           515.7            NaN     51570.0
# 240954                 NaN             NaN            NaN     37600.0
# 50706                  NaN             NaN            NaN     19519.0

# %%
#Define their respective crossfield values
values = [1575.00, 1150.00, 485.00, 1080.00, 646.51, 632.04, 477.70, 376.00, 195.19]
pairs = zip(indexes, values)

# %%
#Replace total rent with the crossfield values and update cf_validation
for idx, value in pairs:
    rentals.loc[[idx], 'totalRent'] = value
    rentals.loc[[idx], 'cf_validation'] = value
rentals.loc[indexes, valCrossfields]
# Out:
#         baseRent  serviceCharge  heatingCosts  crossfield_service  \
# 239533   1325.00         250.00           NaN             1575.00
# 109047    950.00         200.00           NaN             1150.00
# 79903     350.00         135.00           NaN              485.00
# 23490     820.00         260.00           NaN             1080.00
# 197378    487.51         159.00           NaN              646.51
# 16832     460.29         171.75           NaN              632.04
# 97927     427.70          50.00          38.0              477.70
# 240954    266.00         110.00           NaN              376.00
# 50706     184.00          11.19           NaN              195.19
#
#         crossfield_heating  crossfield_all  cf_validation  totalRent
# 239533                 NaN             NaN        1575.00    1575.00
# 109047                 NaN             NaN        1150.00    1150.00
# 79903                  NaN             NaN         485.00     485.00
# 23490                  NaN             NaN        1080.00    1080.00
# 197378                 NaN             NaN         646.51     646.51
# 16832                  NaN             NaN         632.04     632.04
# 97927                465.7           515.7         477.70     477.70
# 240954                 NaN             NaN         376.00     376.00
# 50706                  NaN             NaN         195.19     195.19

# %%
rentals['cf_validation'] = np.select(conditions, choices, default = np.nan)

# %%
rentals.loc[rentals.cf_validation.isnull() & rentals.totalRent.notnull(), valCrossfields]. \
            sort_values(by = 'totalRent', ascending = False).head(20)
# Out:
#         baseRent  serviceCharge  heatingCosts  crossfield_service  \
# 57237    13000.0        1550.00           NaN            14550.00
# 209250    1050.0         180.00          70.0             1230.00
# 38143    10500.0        2000.00           NaN            12500.00
# 255251    1050.0         200.00         100.0             1250.00
# 65562     9500.0         760.00           NaN            10260.00
# 214772    6580.0         780.00           NaN             7360.00
# 9055      8700.0         405.00         245.0             9105.00
# 101948    6109.0         690.00           NaN             6799.00
# 201485    5680.0        1665.00           NaN             7345.00
# 204189    5800.0        1739.56           NaN             7539.56
# 29245     4910.0        1700.00           NaN             6610.00
# 28548     5736.8        1118.68           NaN             6855.48
# 243779    5736.6        1118.64           NaN             6855.24
# 227323    5820.0         800.00           NaN             6620.00
# 109961    5500.0        1045.00           NaN             6545.00
# 174541    5500.0        1000.00           NaN             6500.00
# 194155    5700.0         800.00           NaN             6500.00
# 137251    5700.0         800.00           NaN             6500.00
# 81769     5163.0         911.00           NaN             6074.00
# 2790      5000.0           0.00           0.0             5000.00
#
#         crossfield_heating  crossfield_all  cf_validation  totalRent
# 57237                  NaN             NaN            NaN   15000.00
# 209250              1120.0          1300.0            NaN   13500.00
# 38143                  NaN             NaN            NaN   11900.00
# 255251              1150.0          1350.0            NaN   11250.00
# 65562                  NaN             NaN            NaN    9774.00
# 214772                 NaN             NaN            NaN    8780.00
# 9055                8945.0          9350.0            NaN    8706.00
# 101948                 NaN             NaN            NaN    8124.00
# 201485                 NaN             NaN            NaN    7745.00
# 204189                 NaN             NaN            NaN    7539.56
# 29245                  NaN             NaN            NaN    7000.00
# 28548                  NaN             NaN            NaN    6855.48
# 243779                 NaN             NaN            NaN    6855.24
# 227323                 NaN             NaN            NaN    6800.00
# 109961                 NaN             NaN            NaN    6725.00
# 174541                 NaN             NaN            NaN    6700.00
# 194155                 NaN             NaN            NaN    6600.00
# 137251                 NaN             NaN            NaN    6600.00
# 81769                  NaN             NaN            NaN    6524.00
# 2790                5000.0          5000.0            NaN    6500.00

# %% [markdown]
# ## 5.3 Reviewing Data Completeness

# %%
#To determine counts and percentage of valid entries
missing = pd.concat([rentals.isnull().sum(), rentals.isnull().mean() * 100], axis = 1)
missing.columns = ['num_mssg', 'pct_mssg']
missing.sort_values(by = 'num_mssg', ascending = False)
# Out:
#                           num_mssg   pct_mssg
# telekomHybridUploadSpeed    223830  83.254603
# electricityBasePrice        222004  82.575414
# electricityKwhPrice         222004  82.575414
# energyEfficiencyClass       191063  71.066766
# lastRefurbish               188145  69.981402
# crossfield_all              183545  68.270411
# crossfield_heating          183332  68.191185
# heatingCosts                183332  68.191185
# noParkSpaces                175798  65.388879
# petsAllowed                 114573  42.615957
# interiorQual                112665  41.906267
# thermalChar                 106506  39.615399
# numberOfFloors               97732  36.351869
# houseNumber                  71018  26.415473
# streetPlain                  71013  26.413614
# condition                    68489  25.474800
# cf_validation                67533  25.119211
# yearConstructed              57436  21.363586
# yearConstructedRange         57045  21.218151
# firingTypes                  56964  21.188023
# facilities                   52924  19.685326
# floor                        51309  19.084620
# heatingType                  44856  16.684397
# totalRent                    40517  15.070485
# typeOfFlat                   36614  13.618747
# telekomUploadSpeed           33358  12.407662
# telekomTvOffer               32619  12.132788
# description                  19747   7.344988
# crossfield_service            6909   2.569834
# serviceCharge                 6909   2.569834
# pricetrend                    1832   0.681421
# date                             0   0.000000
# garden                           0   0.000000
# regio3                           0   0.000000
# regio2                           0   0.000000
# livingSpaceRange                 0   0.000000
# regio1                           0   0.000000
# noRoomsRange                     0   0.000000
# noRooms                          0   0.000000
# geo_plz                          0   0.000000
# baseRentRange                    0   0.000000
# lift                             0   0.000000
# geo_krs                          0   0.000000
# livingSpace                      0   0.000000
# baseRent                         0   0.000000
# cellar                           0   0.000000
# geo_bln                          0   0.000000
# hasKitchen                       0   0.000000
# scoutId                          0   0.000000
# picturecount                     0   0.000000
# balcony                          0   0.000000
# newlyConst                       0   0.000000
# street                           0   0.000000

# %% [markdown]
# - Let's view the completeness count and fraction of bottom twenty features

# %%
_= msno.bar(rentals,filter = 'bottom', n = 20, sort = 'ascending')
_= plt.axhline(y=0.4, color='r', linestyle='-')
_= plt.title('Bottom 20 Incomplete Features with Completeness Fraction and Count', fontsize = 25, color = 'blue')

# %% [markdown]
# - There are seven features that are less than 40% complete, including heatingCosts and electricityKwhPrice. We will filter-out these features from the dataframe.

# %%
#Filter-out features with over 40% missing values
rentals = msno.nullity_filter(rentals,filter = 'top', p =0.4)
rentals.shape
# Out:
# (268850, 44)

# %% [markdown]
# ## 5.4 Checking for Duplicated Rental Units

# %%
#Check for duplicates across all columns except scoutId which is the unique identifier for each listing
rentals_noScoutId = rentals.loc[:, rentals.columns != 'scoutId']
duplicates = rentals_noScoutId.duplicated()
duplicates.sum()
# Out:
# 899

# %% [markdown]
# -There are potentially 900 duplicated rows. We will review the nature of the duplicated rows

# %%
subset = ['houseNumber', 'streetPlain','regio3', 'regio2','regio1','geo_plz', 'baseRent', 'totalRent', 'noRooms']
full_duplicates = rentals_noScoutId.duplicated(keep = False)
rentals.loc[full_duplicates, subset].sort_values(by = ['regio3', 'streetPlain']).head(20)
# Out:
#        houseNumber           streetPlain  \
# 122607         NaN                   NaN
# 135689         NaN                   NaN
# 54879          NaN                   NaN
# 226122         NaN                   NaN
# 25677           27        Dörpfeldstraße
# 86827            5        Dörpfeldstraße
# 207406           5        Dörpfeldstraße
# 235965          27        Dörpfeldstraße
# 267457          27        Dörpfeldstraße
# 26652          NaN                   NaN
# 179287         NaN                   NaN
# 81959          NaN                   NaN
# 256892         NaN                   NaN
# 106996          72  Altchemnitzer_Straße
# 229185          72  Altchemnitzer_Straße
# 23252           19     Lothringer_Straße
# 214060          19     Lothringer_Straße
# 9740           NaN                   NaN
# 124139         NaN                   NaN
# 160138         NaN                   NaN
#
#                                        regio3         regio2  \
# 122607                       Aachen_Eilendorf         Aachen
# 135689                       Aachen_Eilendorf         Aachen
# 54879                               Abensberg  Kelheim_Kreis
# 226122                              Abensberg  Kelheim_Kreis
# 25677                       Adlershof_Treptow         Berlin
# 86827                       Adlershof_Treptow         Berlin
# 207406                      Adlershof_Treptow         Berlin
# 235965                      Adlershof_Treptow         Berlin
# 267457                      Adlershof_Treptow         Berlin
# 26652                       Adlershof_Treptow         Berlin
# 179287                      Adlershof_Treptow         Berlin
# 81959   Alt_Hohenschönhausen_Hohenschönhausen         Berlin
# 256892  Alt_Hohenschönhausen_Hohenschönhausen         Berlin
# 106996                            Altchemnitz       Chemnitz
# 229185                            Altchemnitz       Chemnitz
# 23252                             Altchemnitz       Chemnitz
# 214060                            Altchemnitz       Chemnitz
# 9740                            Alte_Neustadt      Magdeburg
# 124139                          Alte_Neustadt      Magdeburg
# 160138                          Alte_Neustadt      Magdeburg
#
#                      regio1  geo_plz  baseRent  totalRent  noRooms
# 122607  Nordrhein_Westfalen    52080    650.00        NaN      3.0
# 135689  Nordrhein_Westfalen    52080    650.00        NaN      3.0
# 54879                Bayern    93326    600.00     750.00      2.0
# 226122               Bayern    93326    600.00     750.00      2.0
# 25677                Berlin    12489   1330.00    1710.00      5.0
# 86827                Berlin    12489    621.35     763.05      1.0
# 207406               Berlin    12489    621.35     763.05      1.0
# 235965               Berlin    12489   1330.00    1710.00      5.0
# 267457               Berlin    12489   1330.00    1710.00      5.0
# 26652                Berlin    12489    600.00     700.00      2.0
# 179287               Berlin    12489    600.00     700.00      2.0
# 81959                Berlin    13055    760.00     980.00      3.0
# 256892               Berlin    13055    760.00     980.00      3.0
# 106996              Sachsen     9120    299.00     420.00      2.0
# 229185              Sachsen     9120    299.00     420.00      2.0
# 23252               Sachsen     9120    165.00     260.58      1.0
# 214060              Sachsen     9120    165.00     260.58      1.0
# 9740         Sachsen_Anhalt    39106    410.00     520.00      2.0
# 124139       Sachsen_Anhalt    39106    410.00     520.00      2.0
# 160138       Sachsen_Anhalt    39106    400.00     500.00      2.0

# %% [markdown]
# - We will drop duplicated rows

# %%
column_names = rentals.loc[:, rentals.columns != 'scoutId'].columns

# %%
rentals.shape
# Out:
# (268850, 44)

# %%
rentals.drop_duplicates(subset = column_names, inplace = True)
rentals.shape
# Out:
# (267951, 44)

# %% [markdown]
# ## 5.5 Reviewing Categorical Features
#
# ### 5.5.1 Address Information <br>(houseNumber, geo_bln, geo_krs, street, geo_plz, regio1, regio2,    regio3, streetPlain)</br>

# %%
address = ['houseNumber','street', 'streetPlain', 'regio3', 'regio2','geo_krs','regio1', 'geo_bln', 'geo_plz']
rentals[address].head()
# Out:
#   houseNumber                       street                  streetPlain  \
# 0         244   Sch&uuml;ruferstra&szlig;e              Schüruferstraße
# 1         NaN               no_information                          NaN
# 2           4                    Turnerweg                    Turnerweg
# 3          35  Gl&uuml;ck-Auf-Stra&szlig;e             Glück-Auf-Straße
# 4          10  Hermann-Henrich-Meier-Allee  Hermann-Henrich-Meier-Allee
#
#                        regio3               regio2              geo_krs  \
# 0                     Schüren             Dortmund             Dortmund
# 1              Böhl_Iggelheim    Rhein_Pfalz_Kreis    Rhein_Pfalz_Kreis
# 2  Äußere_Neustadt_Antonstadt              Dresden              Dresden
# 3                    Freiberg  Mittelsachsen_Kreis  Mittelsachsen_Kreis
# 4           Neu_Schwachhausen               Bremen               Bremen
#
#                 regio1              geo_bln  geo_plz
# 0  Nordrhein_Westfalen  Nordrhein_Westfalen    44269
# 1      Rheinland_Pfalz      Rheinland_Pfalz    67459
# 2              Sachsen              Sachsen     1097
# 3              Sachsen              Sachsen     9599
# 4               Bremen               Bremen    28213

# %% [markdown]
# - We notice that street seems identical to streetPlain, regio2 seems identical to geo_krs and regio1 seems identical to geo_bln
# - We will review these relationships

# %%
#Check if there are records where regio1 is not identical to geo_bln 
(rentals["regio1"] != rentals['geo_bln']).sum()
# Out:
# 0

# %% [markdown]
# - regio1 is the state and it is always equal to geo_bln. We will drop geo_bln

# %%
#Number of categories
rentals.regio1.nunique()
# Out:
# 16

# %%
#Review category names and how many records in which they appear
rentals.regio1.value_counts()
# Out:
# Nordrhein_Westfalen       62744
# Sachsen                   57848
# Bayern                    21566
# Sachsen_Anhalt            20049
# Hessen                    17744
# Niedersachsen             16564
# Baden_Württemberg         16058
# Berlin                    10353
# Thüringen                  8363
# Rheinland_Pfalz            8351
# Brandenburg                6921
# Schleswig_Holstein         6640
# Mecklenburg_Vorpommern     6624
# Hamburg                    3741
# Bremen                     2960
# Saarland                   1425
# Name: regio1, dtype: int64

# %%
#Check if there are records where regio1 is not identical to geo_bln 
(rentals["regio2"] != rentals['geo_krs']).sum()
# Out:
# 0

# %% [markdown]
# - regio2 is the district and it is always equal to geo_krs. We will drop geo_krs

# %%
#Number of categories
rentals.regio2.nunique()
# Out:
# 419

# %%
rentals.regio2.unique()
# Out:
# array(['Dortmund', 'Rhein_Pfalz_Kreis', 'Dresden', 'Mittelsachsen_Kreis',
#        'Bremen', 'Schleswig_Flensburg_Kreis', 'Emmendingen_Kreis',
#        'Gelsenkirchen', 'Chemnitz', 'Südliche_Weinstraße_Kreis', 'Hamm',
#        'Weimar', 'Main_Kinzig_Kreis', 'Duisburg', 'Göttingen_Kreis',
#        'Neumünster', 'Stuttgart', 'Leipzig', 'München', 'Hamburg',
#        'Braunschweig', 'Esslingen_Kreis', 'Magdeburg', 'Schwerin',
#        'Passau', 'Mettmann_Kreis', 'Vogtlandkreis', 'Groß_Gerau_Kreis',
#        'Sächsische_Schweiz_Osterzgebirge_Kreis', 'Görlitz_Kreis',
#        'Rheinisch_Bergischer_Kreis', 'Essen', 'Meißen_Kreis', 'Mannheim',
#        'Wesermarsch_Kreis', 'Hochsauerlandkreis', 'Unna_Kreis',
#        'Bautzen_Kreis', 'Berlin', 'Frankfurt_am_Main', 'Halle_Saale',
#        'Steinburg_Kreis', 'Aschaffenburg', 'Oder_Spree_Kreis',
#        'Bremerhaven', 'Zwickau_Kreis', 'Nordsachsen_Kreis',
#        'Mansfeld_Südharz_Kreis', 'Alzey_Worms_Kreis', 'Gießen_Kreis',
#        'Main_Taunus_Kreis', 'Zwickau', 'Wuppertal', 'Viersen_Kreis',
#        'Düsseldorf', 'Gera', 'Böblingen_Kreis', 'Würzburg',
#        'Kitzingen_Kreis', 'Stendal_Kreis', 'Nordvorpommern_Kreis',
#        'Rhein_Erft_Kreis', 'Mülheim_an_der_Ruhr', 'Heilbronn',
#        'Hersfeld_Rotenburg_Kreis', 'Aachen_Kreis', 'Erzgebirgskreis',
#        'Baden_Baden', 'Tuttlingen_Kreis', 'Nürnberg', 'Heinsberg_Kreis',
#        'Remscheid', 'Märkisch_Oderland_Kreis', 'Wiesbaden',
#        'Wetteraukreis', 'Kassel', 'Bielefeld', 'Salzlandkreis', 'Aachen',
#        'Harburg_Kreis', 'Höxter_Kreis', 'Germersheim_Kreis',
#        'Brandenburg_an_der_Havel', 'Leipzig_Kreis', 'Aurich_Kreis',
#        'Herzogtum_Lauenburg_Kreis', 'Karlsruhe', 'Frankenthal_Pfalz',
#        'Rheingau_Taunus_Kreis', 'Nordwestmecklenburg_Kreis',
#        'Ostvorpommern_Kreis', 'Emden', 'Rems_Murr_Kreis',
#        'Altmarkkreis_Salzwedel', 'Straubing', 'Peine_Kreis',
#        'Paderborn_Kreis', 'Düren_Kreis', 'Fürstenfeldbruck_Kreis', 'Kiel',
#        'Unstrut_Hainich_Kreis', 'Ludwigslust_Kreis', 'Flensburg',
#        'Borken_Kreis', 'Krefeld', 'Lörrach_Kreis', 'Saalekreis',
#        'Wesel_Kreis', 'Recklinghausen_Kreis', 'Hagen',
#        'Grafschaft_Bentheim_Kreis', 'Goslar_Kreis', 'Bergstraße_Kreis',
#        'Börde_Kreis', 'Potsdam', 'Kusel_Kreis', 'Burgenlandkreis',
#        'Holzminden_Kreis', 'Bad_Doberan_Kreis', 'Biberach_Kreis',
#        'Coburg', 'Köln', 'Aschaffenburg_Kreis', 'Görlitz',
#        'Dessau_Roßlau', 'Harz_Kreis', 'Ludwigsburg_Kreis', 'Herne',
#        'Bad_Dürkheim_Kreis', 'Wittenberg_Kreis', 'Fürth',
#        'Eichstätt_Kreis', 'Bochum', 'Pfaffenhofen_an_der_Ilm_Kreis',
#        'Märkischer_Kreis', 'Trier', 'Rhein_Sieg_Kreis', 'Hannover',
#        'Limburg_Weilburg_Kreis', 'Mönchengladbach', 'Bonn',
#        'Anhalt_Bitterfeld_Kreis', 'Herford_Kreis', 'Neuss_Rhein_Kreis',
#        'Plauen', 'Soest_Kreis', 'Erding_Kreis', 'Dahme_Spreewald_Kreis',
#        'Mainz', 'Kleve_Kreis', 'Reutlingen_Kreis', 'Offenbach_Kreis',
#        'Segeberg_Kreis', 'Emsland_Kreis', 'Hochtaunuskreis',
#        'Schwarzwald_Baar_Kreis', 'Oberbergischer_Kreis',
#        'Wunsiedel_im_Fichtelgebirge_Kreis', 'Hildburghausen_Kreis',
#        'Wismar', 'Heilbronn_Kreis', 'Hannover_Kreis', 'Pirmasens',
#        'Schmalkalden_Meiningen_Kreis', 'Ostalbkreis',
#        'Oldenburg_Oldenburg', 'Mayen_Koblenz_Kreis', 'Ennepe_Ruhr_Kreis',
#        'Uckermark_Kreis', 'Mainz_Bingen_Kreis', 'Erfurt',
#        'Helmstedt_Kreis', 'Pinneberg_Kreis', 'Gütersloh_Kreis',
#        'Starnberg_Kreis', 'Siegen_Wittgenstein_Kreis', 'Fulda_Kreis',
#        'Würzburg_Kreis', 'Oberspreewald_Lausitz_Kreis', 'Göppingen_Kreis',
#        'Werra_Meißner_Kreis', 'Lüneburg_Kreis', 'Wilhelmshaven',
#        'Wolfsburg', 'Northeim_Kreis', 'Rhein_Lahn_Kreis',
#        'Karlsruhe_Kreis', 'Freising_Kreis', 'Lübeck',
#        'Minden_Lübbecke_Kreis', 'Rastatt_Kreis', 'Unterallgäu_Kreis',
#        'Eisenach', 'Spree_Neiße_Kreis', 'Bad_Tölz_Wolfratshausen_Kreis',
#        'Rendsburg_Eckernförde_Kreis', 'Augsburg',
#        'Neustadt_a.d._Aisch_Bad_Windsheim_Kreis', 'Oberhavel_Kreis',
#        'Schwalm_Eder_Kreis', 'Stralsund', 'Prignitz_Kreis', 'Hoyerswerda',
#        'Straubing_Bogen_Kreis', 'Darmstadt_Dieburg_Kreis', 'Landshut',
#        'Cochem_Zell_Kreis', 'Bad_Kreuznach_Kreis', 'Solingen',
#        'Heidelberg', 'Hof', 'Neubrandenburg', 'Osnabrück_Kreis',
#        'Landshut_Kreis', 'Donau_Ries_Kreis', 'Güstrow_Kreis',
#        'Plön_Kreis', 'Koblenz', 'Alb_Donau_Kreis', 'Heidenheim_Kreis',
#        'Bodenseekreis', 'Teltow_Fläming_Kreis', 'Westerwaldkreis',
#        'Celle_Kreis', 'Potsdam_Mittelmark_Kreis', 'Hildesheim_Kreis',
#        'Verden_Kreis', 'Rhein_Neckar_Kreis', 'Havelland_Kreis',
#        'Dachau_Kreis', 'Rotenburg_Wümme_Kreis', 'Ostholstein_Kreis',
#        'Pforzheim', 'Suhl', 'Stormarn_Kreis', 'Eichsfeld_Kreis',
#        'Darmstadt', 'Regensburg', 'Nordhausen_Kreis', 'Sonneberg_Kreis',
#        'Cottbus', 'Forchheim_Kreis', 'Erlangen', 'Nienburg_Weser_Kreis',
#        'Waldeck_Frankenberg_Kreis', 'Dithmarschen_Kreis',
#        'Diepholz_Kreis', 'Augsburg_Kreis', 'Deggendorf_Kreis',
#        'Oberhausen', 'Neustadt_an_der_Weinstraße', 'Münster',
#        'Osterode_am_Harz_Kreis', 'Freudenstadt_Kreis',
#        'Marburg_Biedenkopf_Kreis', 'Stade_Kreis', 'Birkenfeld_Kreis',
#        'Cuxhaven_Kreis', 'Rottal_Inn_Kreis', 'Rügen_Kreis',
#        'München_Kreis', 'Osnabrück', 'Gotha_Kreis', 'Offenbach_am_Main',
#        'Stadtverband_Saarbrücken_Kreis', 'Hof_Kreis', 'Kyffhäuserkreis',
#        'Freiburg_im_Breisgau', 'Ravensburg_Kreis', 'Hameln_Pyrmont_Kreis',
#        'Saalfeld_Rudolstadt_Kreis', 'Rostock', 'Saarlouis_Kreis',
#        'Parchim_Kreis', 'Schwäbisch_Hall_Kreis', 'Bamberg_Kreis',
#        'Weilheim_Schongau_Kreis', 'Lippe_Kreis', 'Müritz_Kreis',
#        'Steinfurt_Kreis', 'Traunstein_Kreis', 'Ebersberg_Kreis',
#        'Neuwied_Kreis', 'Kelheim_Kreis', 'Weimarer_Land_Kreis',
#        'Saarpfalz_Kreis', 'Vechta_Kreis', 'Bitburg_Prüm_Kreis',
#        'Ahrweiler_Kreis', 'Greifswald', 'Calw_Kreis', 'Gifhorn_Kreis',
#        'Uelzen_Kreis', 'Altenburger_Land_Kreis', 'Ilm_Kreis',
#        'Trier_Saarburg_Kreis', 'Lahn_Dill_Kreis', 'Worms',
#        'Berchtesgadener_Land_Kreis', 'Breisgau_Hochschwarzwald_Kreis',
#        'Oldenburg_Kreis', 'Barnim_Kreis', 'Erlangen_Höchstadt_Kreis',
#        'Main_Spessart_Kreis', 'Rosenheim_Kreis', 'Bottrop',
#        'Ludwigshafen_am_Rhein', 'Elbe_Elster_Kreis', 'Warendorf_Kreis',
#        'Kassel_Kreis', 'Mecklenburg_Strelitz_Kreis',
#        'Jerichower_Land_Kreis', 'Lüchow_Dannenberg_Kreis', 'Greiz_Kreis',
#        'Euskirchen_Kreis', 'Regensburg_Kreis', 'Kaiserslautern_Kreis',
#        'Salzgitter', 'Weißenburg_Gunzenhausen_Kreis', 'Ulm',
#        'Altötting_Kreis', 'Landsberg_am_Lech_Kreis', 'Günzburg_Kreis',
#        'Amberg_Sulzbach_Kreis', 'Wartburgkreis', 'Neu_Ulm_Kreis',
#        'Lichtenfels_Kreis', 'Friesland_Kreis', 'Tübingen_Kreis',
#        'Zollernalbkreis', 'Enzkreis', 'Miltenberg_Kreis',
#        'Kaiserslautern', 'Schaumburg_Kreis', 'Waldshut_Kreis',
#        'Delmenhorst', 'Bayreuth', 'Jena', 'Sömmerda_Kreis',
#        'Nordfriesland_Kreis', 'Leer_Kreis',
#        'Dillingen_an_der_Donau_Kreis', 'Nürnberger_Land_Kreis',
#        'Ostprignitz_Ruppin_Kreis', 'Ingolstadt', 'Bad_Kissingen_Kreis',
#        'Saale_Holzland_Kreis', 'Kaufbeuren', 'Speyer', 'Ansbach_Kreis',
#        'Ammerland_Kreis', 'Rottweil_Kreis', 'Mühldorf_am_Inn_Kreis',
#        'Weiden_in_der_Oberpfalz', 'Frankfurt_Oder',
#        'Garmisch_Partenkirchen_Kreis', 'Main_Tauber_Kreis',
#        'Ostallgäu_Kreis', 'Leverkusen', 'Rosenheim', 'Coburg_Kreis',
#        'Neumarkt_in_der_Oberpfalz_Kreis', 'Aichach_Friedberg_Kreis',
#        'Neunkirchen_Kreis', 'Coesfeld_Kreis', 'Lindau_Bodensee_Kreis',
#        'Ortenaukreis', 'Rhein_Hunsrück_Kreis', 'Osterholz_Kreis',
#        'Merzig_Wadern_Kreis', 'Heidekreis', 'Wolfenbüttel_Kreis',
#        'Dingolfing_Landau_Kreis', 'Südwestpfalz_Kreis',
#        'Bernkastel_Wittlich_Kreis', 'Bayreuth_Kreis', 'Schweinfurt_Kreis',
#        'Demmin_Kreis', 'Passau_Kreis', 'Miesbach_Kreis', 'Ansbach',
#        'Konstanz_Kreis', 'Fürth_Kreis', 'Tirschenreuth_Kreis',
#        'Neckar_Odenwald_Kreis', 'Altenkirchen_Westerwald_Kreis',
#        'Soltau_Fallingbostel_Kreis', 'Landau_in_der_Pfalz',
#        'Uecker_Randow_Kreis', 'Zweibrücken',
#        'Neuburg_Schrobenhausen_Kreis', 'Amberg', 'Donnersbergkreis',
#        'Cloppenburg_Kreis', 'Hohenlohekreis', 'Roth_Kreis', 'Bamberg',
#        'Schweinfurt', 'Vulkaneifel_Kreis', 'Vogelsbergkreis',
#        'Schwandorf_Kreis', 'Cham_Kreis', 'Sigmaringen_Kreis',
#        'Oberallgäu_Kreis', 'Regen_Kreis', 'Memmingen', 'Kempten_Allgäu',
#        'Freyung_Grafenau_Kreis', 'Odenwaldkreis', 'Olpe_Kreis',
#        'Saale_Orla_Kreis', 'Sankt_Wendel_Kreis', 'Kulmbach_Kreis',
#        'Schwabach', 'Wittmund_Kreis', 'Haßberge_Kreis',
#        'Rhön_Grabfeld_Kreis', 'Kronach_Kreis',
#        'Neustadt_a.d._Waldnaab_Kreis'], dtype=object)

# %% [markdown]
# - We notice that many of the districts have Kreis at the end of its name. We will remove these.

# %%
rentals.regio2 = rentals.regio2.str.replace('_Kreis', '')
rentals.regio2.nunique()
# Out:
# 394

# %%
#We can take a sample of street and streetPlain data to verify that they are identical
rentals[['street', 'streetPlain']].sample(10)
# Out:
#                                 street            streetPlain
# 132139                  R&ouml;merstr.              Römerstr.
# 80007                   Auerhammerstr.         Auerhammerstr.
# 33227      Heinrich-Heine-Stra&szlig;e  Heinrich-Heine-Straße
# 174829                  no_information                    NaN
# 242517             Logabirumer strasse    Logabirumer_strasse
# 154298                 Bismarckstrasse        Bismarckstrasse
# 177508    L&uuml;neburger Stra&szlig;e      Lüneburger_Straße
# 92198                   no_information                    NaN
# 248721            Sch&ouml;ne Aussicht        Schöne_Aussicht
# 75718   Stra&szlig;berger Stra&szlig;e     Straßberger_Straße

# %% [markdown]
# - street and streetPlain are always identical. We will drop street

# %%
#Number of categories
rentals.streetPlain.nunique()
# Out:
# 54490

# %%
#Review category names and how many records in which they appear
rentals.streetPlain.value_counts().head()
# Out:
# Hauptstraße         911
# Bahnhofstraße       834
# Leipziger_Straße    425
# Goethestraße        406
# Bahnhofstr.         401
# Name: streetPlain, dtype: int64

# %% [markdown]
# - We note that streetPlain has a high cardinatliy

# %% [markdown]
# - regio3 is the town or municipality

# %%
#Review category names and how many records in which they appear
rentals.regio3.nunique()
# Out:
# 8684

# %%
rentals.regio3.unique()[:10]
# Out:
# array(['Schüren', 'Böhl_Iggelheim', 'Äußere_Neustadt_Antonstadt',
#        'Freiberg', 'Neu_Schwachhausen', 'Struxdorf', 'St._Magnus',
#        'Denzlingen', 'Bulmke_Hüllen', 'Sonnenberg'], dtype=object)

# %%
#Drop redundant columns
rentals.drop(columns = ['street', 'geo_bln', 'geo_krs'], axis = 1, inplace = True)

# %%
#Rename regio1, regio2 and regio3
rentals = rentals.rename(columns={'regio1': 'state', 'regio2': 'district', 'regio3': 'town_municipality'})

# %% [markdown]
# - Laslty we note that streetPlain and houseNumber have a high cardinality and missing values. In addition, our analysis will not extend to the particular address. We will use the zip code as a rough approximations for address information. We will therefore drop streetPlain and houseNumber

# %%
#Drop streetPlain and houseNumber
rentals.drop(columns =['streetPlain', 'houseNumber'], inplace = True)

# %% [markdown]
# ### 5.5.3 Reviewing Remaining Categorical Features

# %%
rentals.select_dtypes('object').describe()
# Out:
#                       state      heatingType telekomTvOffer firingTypes  \
# count                267951           223242         235527      211199
# unique                   16               13              3         132
# top     Nordrhein_Westfalen  central_heating  ONE_YEAR_FREE         gas
# freq                  62744           128563         226940      110519
#
#         condition interiorQual petsAllowed typeOfFlat district  \
# count      199628       155652      153796     231453   267951
# unique         10            4           3         10      394
# top     well_kept       normal  negotiable  apartment  Leipzig
# freq        66392        81649       91683     131051    15963
#
#        town_municipality                                        description  \
# count             267951                                             248264
# unique              8684                                             212621
# top           Innenstadt  + MEIN GUENTZ - Quartier der Generationen\r\n+...
# freq                4733                                                213
#
#        facilities
# count      215187
# unique     189526
# top       Laminat
# freq          207

# %% [markdown]
# #### 5.5.3.1 firingTypes

# %% [markdown]
# - firingTypes gives us a sense of the kind of fuel used in the apartment. heatingType gives us a similar indication of how the apartment is powered. We will drop this feature as well.

# %%
rentals.firingTypes.nunique()
# Out:
# 132

# %%
rentals.firingTypes.value_counts(ascending = False)[:20]
# Out:
# gas                                     110519
# district_heating                         49189
# oil                                      18115
# natural_gas_light                        10059
# electricity                               4829
# natural_gas_heavy                         4535
# pellet_heating                            2474
# geothermal                                2429
# gas:electricity                           1353
# local_heating                              924
# environmental_thermal_energy               896
# combined_heat_and_power_fossil_fuels       860
# steam_district_heating                     785
# liquid_gas                                 451
# solar_heating                              443
# district_heating:electricity               439
# heat_supply                                389
# solar_heating:gas                          385
# gas:district_heating                       258
# wood_chips                                 191
# Name: firingTypes, dtype: int64

# %% [markdown]
# - Most units are fueled by gas. We observe a format of gas:electricity indicating the use of multiple fuels. We can determine if there are others like this

# %%
rentals.loc[rentals.firingTypes.str.contains(':', na = False), 'firingTypes'].head(10)
# Out:
# 7                     gas:electricity
# 105                   gas:electricity
# 150    district_heating:local_heating
# 296              gas:district_heating
# 334                 solar_heating:gas
# 355                   gas:electricity
# 467             gas:natural_gas_light
# 517                 solar_heating:gas
# 692                 solar_heating:gas
# 719                   gas:electricity
# Name: firingTypes, dtype: object

# %%
# Split the data on ':' to get a sense for the extent of the values
rentals["firingTypes"].str.split(":", expand = True).notnull().sum()
# Out:
# 0     211199
# 1       3402
# 2         69
# 3         17
# 4          4
# 5          4
# 6          2
# 7          2
# 8          2
# 9          2
# 10         2
# 11         2
# 12         1
# dtype: int64

# %% [markdown]
# - We note that the first column has most of the data. We will take the values of this first column as values for firingTypes

# %%
rentals.firingTypes = rentals.firingTypes.str.split(':', expand = True)[0]

# %%
#Verify no values have ':'
rentals.firingTypes.str.contains(':', na = False).sum()
# Out:
# 0

# %% [markdown]
# #### 5.5.3.2 telekomTvOffer

# %% [markdown]
# - We notice that telekomTvOffer has ONE_YEAR_FREE in 96% of the cases. We can probably use this for our missing values. But we should take a closer look at the categories of these features.

# %% [markdown]
# - 'telekomTvOffer': Tells us if tv is included with rent. Previously determined that top category is ONE_YEAR_FREE at 96% and that 25% of its values missing. May consider replacing nan values with ONE_YEAR_FREE.

# %%
#Determine counts of telekomTvOffer categories
rentals.telekomTvOffer.value_counts(dropna = False)
# Out:
# ONE_YEAR_FREE    226940
# NaN               32424
# NONE               4951
# ON_DEMAND          3636
# Name: telekomTvOffer, dtype: int64

# %% [markdown]
# - Even though telekomTvOffer has ONE_YEAR_FREE as its prominent category at over 96%, we recognize that this is an incentive. Incentives are typically advertized, so it is very likely that if a tv offer is not provided it is not available. We cannot input this feature. We also note that this feature has low variability, so is likely to add limited value to analysis. We will leave feature for now as-is.

# %% [markdown]
# #### 5.5.3.3 condition

# %% [markdown]
# - 'condition': Indicates appearance of apartment. Previously determined top category as 'well_kept' at 33% and over 25% of its values are missing.

# %%
#Review counts of condition categories
rentals.condition.value_counts(dropna = False)
# Out:
# NaN                                   68323
# well_kept                             66392
# refurbished                           26886
# fully_renovated                       26296
# mint_condition                        21866
# first_time_use                        21793
# modernized                            17184
# first_time_use_after_refurbishment    15605
# negotiable                             2232
# need_of_renovation                     1370
# ripe_for_demolition                       4
# Name: condition, dtype: int64

# %% [markdown]
# - It is unlikely that we can fill missing values for 'condition' because it could be any of the 10 categories, however, we can delete those records with values corresponding to 'need_of_renovation' and 'ripe_for_demolition' because we are only interested in liveable apartments.

# %%
#Select rows with a condition of need_of_renovation and ripe_for_demolition
bad_units = (rentals.condition == 'need_of_renovation') | (rentals.condition == 'ripe_for_demolition')

# %%
#Select only rows of dataframe with livable units
rentals = rentals[~bad_units]

# %%
#Verify there are no records with unlivable units
rentals.condition.value_counts(dropna = False)
# Out:
# NaN                                   68323
# well_kept                             66392
# refurbished                           26886
# fully_renovated                       26296
# mint_condition                        21866
# first_time_use                        21793
# modernized                            17184
# first_time_use_after_refurbishment    15605
# negotiable                             2232
# Name: condition, dtype: int64

# %% [markdown]
# #### 5.5.3.4 interiorQual

# %%
rentals.interiorQual.value_counts(dropna = False)
# Out:
# NaN              111785
# normal            81063
# sophisticated     64432
# luxury             7606
# simple             1691
# Name: interiorQual, dtype: int64

# %% [markdown]
# - It is unlikely that we can fill missing values for interiorQual.

# %% [markdown]
# #### 5.5.3.5 petsAllowed

# %%
rentals.petsAllowed.value_counts(dropna = False)
# Out:
# NaN           113663
# negotiable     91059
# no             51673
# yes            10182
# Name: petsAllowed, dtype: int64

# %% [markdown]
# - It is unlikely that we can fill missing values for petsAllowed.

# %% [markdown]
# #### 5.5.3.6 heatingType

# %% [markdown]
# - 'heatingType': Indicates how the apartment is heated. Previously determined top category as 'central_heating' at 58% and 17% of its values are missing.

# %%
#Review count of heatingType categories
rentals.heatingType.value_counts(dropna = False)
# Out:
# central_heating                   127919
# NaN                                44549
# district_heating                   24548
# gas_heating                        19739
# self_contained_central_heating     18873
# floor_heating                      17610
# oil_heating                         4992
# heat_pump                           2734
# combined_heat_and_power_plant       1971
# night_storage_heater                1303
# wood_pellet_heating                  958
# electric_heating                     892
# stove_heating                        323
# solar_heating                        166
# Name: heatingType, dtype: int64

# %% [markdown]
# - Unlikely to fill missing values right now because they could fall under any of the 13 categories. Will leave as-is.

# %% [markdown]
# #### 5.5.3.7 typeOfFlat

# %% [markdown]
# - 'typeOfFlat': Indicates the style of apartment. Previously determined top category as 'apartment' at 57% and about 13% of its values are missing.

# %%
#Review counts of typeOfFlat categories
rentals.typeOfFlat.value_counts(dropna = False)
# Out:
# apartment              130225
# NaN                     36396
# roof_storey             34499
# ground_floor            31267
# other                    9455
# maisonette               9276
# raised_ground_floor      5592
# penthouse                3546
# terraced_flat            3366
# half_basement            2003
# loft                      952
# Name: typeOfFlat, dtype: int64

# %% [markdown]
# -  There is no discernable trend associated with these categories. We will leave this features as-is for now.

# %% [markdown]
# #### 5.5.3.8 facilities & description

# %% [markdown]
# - facilities indicate the types of ammenities the unit has. description provides more details on the unit. These two features are text strings, whose analysis is outside the scope of the project

# %%
rentals[['facilities', 'description']].head()
# Out:
#                                           facilities  \
# 0  Die Wohnung ist mit Laminat ausgelegt. Das Bad...
# 1                                                NaN
# 2  * 9 m² Balkon\n* Bad mit bodengleicher Dusche,...
# 3                                                NaN
# 4  Diese Wohnung wurde neu saniert und ist wie fo...
#
#                                          description
# 0  Die ebenerdig zu erreichende Erdgeschosswohnun...
# 1  Alles neu macht der Mai – so kann es auch für ...
# 2  Der Neubau entsteht im Herzen der Dresdner Neu...
# 3  Abseits von Lärm und Abgasen in Ihre neue Wohn...
# 4  Es handelt sich hier um ein saniertes Mehrfami...

# %%
rentals.drop(columns = ['facilities', 'description'], inplace = True)

# %% [markdown]
# ## 5.6 Reviewing Numerical Features

# %%
numeric = ['int64', 'float64']
rentals.select_dtypes(numeric).head()
# Out:
#    serviceCharge  picturecount  pricetrend  telekomUploadSpeed  totalRent  \
# 0         245.00             6        4.62                10.0      840.0
# 1         134.00             8        3.47                10.0        NaN
# 2         255.00             8        2.72                 2.4     1300.0
# 3          58.15             9        1.53                40.0        NaN
# 4         138.00            19        2.46                 NaN      903.0
#
#      scoutId  yearConstructedRange  baseRent  livingSpace  baseRentRange  \
# 0   96107057                   2.0     595.0        86.00              4
# 1  111378734                   1.0     800.0        89.00              5
# 2  113147523                   9.0     965.0        83.80              6
# 3  108890903                   2.0     343.0        58.15              2
# 4  114751222                   1.0     765.0        84.97              5
#
#    geo_plz  noRooms  thermalChar  floor  numberOfFloors  noRoomsRange  \
# 0    44269      4.0        181.4    1.0             3.0             4
# 1    67459      3.0          NaN    NaN             NaN             3
# 2     1097      3.0          NaN    3.0             4.0             3
# 3     9599      3.0         86.0    3.0             NaN             3
# 4    28213      3.0        188.9    1.0             NaN             3
#
#    livingSpaceRange  crossfield_service  cf_validation
# 0                 4              840.00          840.0
# 1                 4              934.00            NaN
# 2                 4             1220.00            NaN
# 3                 2              401.15            NaN
# 4                 4              903.00          903.0

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
rentals.select_dtypes(numeric).describe().T
# Out:
#                          count         mean         std         min  \
# serviceCharge        259723.00       151.30      309.51        0.00
# picturecount         266577.00         9.79        6.40        0.00
# pricetrend           264753.00         3.39        1.96      -12.33
# telekomUploadSpeed   233510.00        28.80       16.34        1.00
# totalRent            226425.00       824.73     3384.11        0.00
# scoutId              266577.00 106946774.30 12529042.66 28871743.00
# yearConstructedRange 210025.00         3.72        2.74        1.00
# baseRent             266577.00       694.99    19617.73        0.00
# livingSpace          266577.00        74.39      255.83        0.00
# baseRentRange        266577.00         3.77        2.22        1.00
# geo_plz              266577.00     37312.76    27824.75      852.00
# noRooms              266577.00         2.64        2.64        1.00
# thermalChar          161021.00       114.63       61.42        0.10
# floor                215707.00         2.12        3.65       -1.00
# numberOfFloors       169529.00         3.57        6.40        0.00
# noRoomsRange         266577.00         2.57        0.94        1.00
# livingSpaceRange     266577.00         3.07        1.41        1.00
# crossfield_service   259723.00       796.86      704.71        0.00
# cf_validation        199610.00       811.38     3596.55        0.00
#
#                               25%          50%          75%          max
# serviceCharge               95.00       135.00       190.00    146118.00
# picturecount                 6.00         9.00        13.00       121.00
# pricetrend                   2.00         3.39         4.58        14.92
# telekomUploadSpeed          10.00        40.00        40.00       100.00
# totalRent                  470.00       650.00       985.00   1234567.00
# scoutId              106679023.00 111153779.00 113768041.00 115711743.00
# yearConstructedRange         1.00         3.00         5.00         9.00
# baseRent                   338.50       490.00       800.00   9999999.00
# livingSpace                 54.00        67.35        87.00    111111.00
# baseRentRange                2.00         3.00         5.00         9.00
# geo_plz                   9127.00     38667.00     57078.00     99998.00
# noRooms                      2.00         3.00         3.00       999.99
# thermalChar                 79.00       107.00       140.00      1996.00
# floor                        1.00         2.00         3.00       999.00
# numberOfFloors               2.00         3.00         4.00       999.00
# noRoomsRange                 2.00         3.00         3.00         5.00
# livingSpaceRange             2.00         3.00         4.00         7.00
# crossfield_service         447.00       627.00       969.00    146766.29
# cf_validation              465.00       638.00       960.00   1234567.00

# %%
#Plot histograms of numeric features
_ = rentals.select_dtypes(numeric).hist(figsize = (15, 10))
plt.subplots_adjust(hspace= 0.5);

# %% [markdown]
# - The distributions of baseRent, floor, livingSpace, noRooms, numberOfFloors, serviceCharge, thermalChar and totalRent are highly skewed to the right.

# %% [markdown]
# ### 5.6.1 scoutId and geo_plz

# %% [markdown]
# - We first note that scoutId and geo_plz should be objects even though they have numerical representation
# - scoutId is the identification number for the property
# - geo_plz is the zip code for the property

# %%
#Convert scoutId and geo_plz to objects
rentals.scoutId = rentals.scoutId.astype('object')
rentals.geo_plz = rentals.geo_plz.astype('object')
rentals.dtypes['scoutId'], rentals.dtypes['geo_plz']
# Out:
# (dtype('O'), dtype('O'))

# %%
#Change geo_plz to zip_code
rentals = rentals.rename(columns = {'geo_plz': 'zip_code'})

# %% [markdown]
# ### 5.6.2 Reviewing Range Information <br>(yearConstructedRange, baseRentRange, noRoomsRange, livingSpaceRange)</br>

# %% [markdown]
# - yearConstructedRange indicates binned construction years from 1 to 9. Determined that 21% of its values are missing, corresponding to the number of missing values for 'yearConstructed'. These are correlated features. Will drop this feature because it likely includes outliers.

# %% [markdown]
# - baseRentRange indicates binned base rent. Correlates directly with baseRent. Will drop this feature because it likely includes outliers.

# %% [markdown]
# - noRoomsRange indicates binned number of rooms 1 to 5. Redundant feature. Will drop this feature because it likely includes outliers.

# %% [markdown]
# - livingSpaceRange is the size of apartment sorted into 7 categories. Redundant feature. Will drop this feature because it likely includes outliers.

# %%
#Drop redundant features that may inlcude outliers
rentals.drop(columns = ['yearConstructedRange', 'baseRentRange', 'noRoomsRange', 'livingSpaceRange'], inplace = True)
rentals.select_dtypes(numeric).columns
# Out:
# Index(['serviceCharge', 'picturecount', 'pricetrend', 'telekomUploadSpeed',
#        'totalRent', 'baseRent', 'livingSpace', 'noRooms', 'thermalChar',
#        'floor', 'numberOfFloors', 'crossfield_service', 'cf_validation'],
#       dtype='object')

# %%
_ = rentals.select_dtypes(numeric).hist(figsize = (15, 10))
plt.subplots_adjust(hspace= 0.5);

# %% [markdown]
# ### 5.6.3 Reviewing price-related information <br>(baseRent, totalRent, serviceCharge)</br>

# %%
prices = ['baseRent', 'totalRent', 'serviceCharge']

fig, axes = plt.subplots(1, 3, figsize = [20,5])
for idx, price in enumerate(prices):
    _= sns.boxplot(x = price, data = rentals, ax= axes[idx])

# %%
#Review summary statistics for baseRent, totalRent and serviceCharge
rentals.baseRent.describe()
# Out:
# count    266577.00
# mean        694.99
# std       19617.73
# min           0.00
# 25%         338.50
# 50%         490.00
# 75%         800.00
# max     9999999.00
# Name: baseRent, dtype: float64

# %%
bRent_q1, bRent_q99 = rentals.baseRent.quantile(0.001), rentals.baseRent.quantile(0.999)
bRent_q1, bRent_q99
# Out:
# (112.38, 4900.0)

# %%
rentals.totalRent.describe()
# Out:
# count    226425.00
# mean        824.73
# std        3384.11
# min           0.00
# 25%         470.00
# 50%         650.00
# 75%         985.00
# max     1234567.00
# Name: totalRent, dtype: float64

# %%
rentals.serviceCharge.describe()
# Out:
# count   259723.00
# mean       151.30
# std        309.51
# min          0.00
# 25%         95.00
# 50%        135.00
# 75%        190.00
# max     146118.00
# Name: serviceCharge, dtype: float64

# %% [markdown]
# - baseRent indicates the rent without electricity or heating. Has a min value of 0 and max value of 9M euros, likely outliers.

# %% [markdown]
# - totalRent includes baseRent, serviceCharge and heatingCosts. Determined ~ 15% of its values to be missing. Has min value of 0 euros and max value of 15,751,540 euros. Min and max values are extreme for rents.

# %% [markdown]
# - serviceCharge indicates ancillary costs such as electricity or internet. Previously determined that 2.6% of its values are missing. Has a min value of 0 euros and max value of 146,118.0 euros. These may be wrong data.

# %% [markdown]
# - We will capture values within three standard deviations from the mean and deem other values to be outliers

# %%
#rentals.drop(columns = 'totalRent', inplace = True)

# %%
#Creating new variables associated for rent per square meters
rentals['baseRent_per_sqm'] = rentals.baseRent / rentals.livingSpace
rentals['totalRent_per_sqm'] = rentals.totalRent / rentals.livingSpace

# %%
#Viewing stats for baseRent_per_sqm
rentals.baseRent_per_sqm.describe()
# Out:
# count   266566.00
# mean          inf
# std           NaN
# min          0.00
# 25%          5.62
# 50%          7.38
# 75%         10.18
# max           inf
# Name: baseRent_per_sqm, dtype: float64

# %%
#Viewing stats for baseRent_per_sqm
rentals.totalRent_per_sqm.describe()
# Out:
# count   226420.00
# mean          inf
# std           NaN
# min          0.00
# 25%          7.90
# 50%          9.76
# 75%         12.83
# max           inf
# Name: totalRent_per_sqm, dtype: float64

# %%
#Replacing infinities
rentals.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
rentals.baseRent_per_sqm.describe()
# Out:
# count    266503.00
# mean         46.74
# std       19371.84
# min           0.00
# 25%           5.62
# 50%           7.38
# 75%          10.18
# max     9999999.00
# Name: baseRent_per_sqm, dtype: float64

# %%
bRent_sqm_q1, bRent_sqm_q99 = rentals.baseRent_per_sqm.quantile(0.0001), rentals.baseRent_per_sqm.quantile(0.9999)
bRent_sqm_q1, bRent_sqm_q99
# Out:
# (0.0, 97.7378470587599)

# %%
rentals.totalRent_per_sqm.describe()
# Out:
# count   226368.00
# mean        11.75
# std        213.02
# min          0.00
# 25%          7.90
# 50%          9.76
# 75%         12.83
# max     100000.00
# Name: totalRent_per_sqm, dtype: float64

# %%
tRent_sqm_q1, tRent_sqm_q99 = rentals.totalRent_per_sqm.quantile(0.001), rentals.totalRent_per_sqm.quantile(0.999)
tRent_sqm_q1, tRent_sqm_q99
# Out:
# (0.0, 53.484047619054934)

# %%
cols = ['livingSpace','baseRent','totalRent','cf_validation','baseRent_per_sqm', 'serviceCharge', 'condition',\
        'interiorQual']

# %%
lower_baseRent = (rentals.baseRent < bRent_q1) & (rentals.baseRent_per_sqm < bRent_sqm_q1) & \
                (rentals.interiorQual != 'luxury') & (rentals.interiorQual != 'sophisticated')
upper_baseRent = (rentals.baseRent > bRent_q99 ) & (rentals.baseRent_per_sqm > bRent_sqm_q99) & \
                (rentals.interiorQual != 'luxury') & (rentals.interiorQual != 'sophisticated')

# %%
rentals.loc[upper_baseRent, cols].sort_values(by = 'baseRent', ascending = False)
# Out:
#         livingSpace   baseRent  totalRent  cf_validation  baseRent_per_sqm  \
# 264934         1.00 9999999.00        NaN            NaN        9999999.00
# 8406          76.00 1234567.00 1234567.00     1234567.00          16244.30
# 260259        10.00 1000000.00 1000000.00     1000000.00         100000.00
# 176647        47.67   30990.00     449.90            NaN            650.09
# 213625       110.00   20100.00    2390.00            NaN            182.73
# 263502        97.60    9999.00        NaN            NaN            102.45
# 145100        12.00    5000.00        NaN            NaN            416.67
# 267366        20.00    5000.00    1000.00            NaN            250.00
#
#         serviceCharge        condition interiorQual
# 264934            NaN              NaN          NaN
# 8406              NaN              NaN          NaN
# 260259            NaN              NaN          NaN
# 176647          78.00              NaN          NaN
# 213625         140.00        well_kept       normal
# 263502        9999.00  fully_renovated          NaN
# 145100            NaN              NaN          NaN
# 267366            NaN              NaN          NaN

# %%
rentals.loc[rentals.baseRent > rentals.totalRent, cols].head()
# Out:
#       livingSpace  baseRent  totalRent  cf_validation  baseRent_per_sqm  \
# 1119        49.80    210.00       0.00            NaN              4.22
# 1311       120.00    950.00     200.00            NaN              7.92
# 1317        33.00   1100.00    1040.00            NaN             33.33
# 1390       128.00    530.00     450.00            NaN              4.14
# 1701        66.00   1832.00    1509.00            NaN             27.76
#
#       serviceCharge       condition interiorQual
# 1119         105.00             NaN          NaN
# 1311        1150.00       well_kept       normal
# 1317          60.00      modernized          NaN
# 1390          80.00             NaN          NaN
# 1701           0.00  mint_condition          NaN

# %%
rentals['wrong_addition'] = rentals.baseRent + rentals.totalRent

# %%
rentals.loc[(rentals.wrong_addition == rentals.serviceCharge), cols]
# Out:
#         livingSpace  baseRent  totalRent  cf_validation  baseRent_per_sqm  \
# 1311         120.00    950.00     200.00            NaN              7.92
# 5885          75.00    600.00     130.00            NaN              8.00
# 21992         71.26      0.00     180.00         180.00              0.00
# 24858         88.00    390.00     200.00            NaN              4.43
# 33492         94.00   1120.00     250.00            NaN             11.91
# 35630          0.00      0.00       0.00           0.00               NaN
# 44138         74.68      0.00     180.00         180.00              0.00
# 46076         52.00    500.00     115.00            NaN              9.62
# 46213         39.55    826.00     130.00            NaN             20.88
# 47325         32.00    290.00     100.00            NaN              9.06
# 51128         68.00    320.00     140.00            NaN              4.71
# 59325         84.00    800.00     330.00            NaN              9.52
# 59840         78.00    400.00     115.00            NaN              5.13
# 70256         36.36    273.00      85.00            NaN              7.51
# 79919         95.10      0.00       0.00           0.00              0.00
# 91246         67.95    305.00     136.00            NaN              4.49
# 113413        68.35    450.00     220.00            NaN              6.58
# 121653        62.00      0.00       0.00           0.00              0.00
# 124721        63.50    450.00     150.00            NaN              7.09
# 129836        57.05    320.00     120.00            NaN              5.61
# 156433       137.80    593.00     330.72            NaN              4.30
# 182396        68.00    340.00     140.00            NaN              5.00
# 202408        89.53    710.00     260.00            NaN              7.93
# 214504        51.80    549.00     135.00            NaN             10.60
# 214616        75.00      0.00     180.00         180.00              0.00
# 216231        38.73      0.00       0.00           0.00              0.00
#
#         serviceCharge        condition   interiorQual
# 1311          1150.00        well_kept         normal
# 5885           730.00        well_kept            NaN
# 21992          180.00   first_time_use  sophisticated
# 24858          590.00              NaN            NaN
# 33492         1370.00   mint_condition         luxury
# 35630            0.00      refurbished         luxury
# 44138          180.00   first_time_use  sophisticated
# 46076          615.00              NaN            NaN
# 46213          956.00              NaN            NaN
# 47325          390.00              NaN            NaN
# 51128          460.00        well_kept            NaN
# 59325         1130.00              NaN            NaN
# 59840          515.00  fully_renovated         normal
# 70256          358.00        well_kept         normal
# 79919            0.00              NaN            NaN
# 91246          441.00  fully_renovated            NaN
# 113413         670.00  fully_renovated            NaN
# 121653           0.00        well_kept         normal
# 124721         600.00  fully_renovated         normal
# 129836         440.00      refurbished         normal
# 156433         923.72  fully_renovated            NaN
# 182396         480.00              NaN            NaN
# 202408         970.00        well_kept         normal
# 214504         684.00   first_time_use  sophisticated
# 214616         180.00   first_time_use  sophisticated
# 216231           0.00              NaN            NaN

# %%
rentals= rentals[~(rentals.wrong_addition == rentals.serviceCharge)]

# %%
bad_units = (rentals.baseRent_per_sqm > 1000) | (rentals.totalRent_per_sqm > 1000)

# %%
idx = rentals.loc[bad_units, cols].index
rentals.loc[bad_units, cols]
# Out:
#         livingSpace   baseRent  totalRent  cf_validation  baseRent_per_sqm  \
# 7775           1.00    1130.00    1280.00        1280.00           1130.00
# 8406          76.00 1234567.00 1234567.00     1234567.00          16244.30
# 260259        10.00 1000000.00 1000000.00     1000000.00         100000.00
# 264934         1.00 9999999.00        NaN            NaN        9999999.00
#
#         serviceCharge condition   interiorQual
# 7775           150.00       NaN  sophisticated
# 8406              NaN       NaN            NaN
# 260259            NaN       NaN            NaN
# 264934            NaN       NaN            NaN

# %%
idx
# Out:
# Int64Index([7775, 8406, 260259, 264934], dtype='int64')

# %%
remove_idx = [7775,8406,260259,264934]

# %%
rentals = rentals[~rentals.index.isin(remove_idx)]

# %%
bad_units3 = (rentals.baseRent == 0) & rentals.totalRent.isnull()
rentals.loc[bad_units3, cols].sort_values(by = 'baseRent_per_sqm').head()
# Out:
#         livingSpace  baseRent  totalRent  cf_validation  baseRent_per_sqm  \
# 201           45.34      0.00        NaN            NaN              0.00
# 253681       120.00      0.00        NaN            NaN              0.00
# 225352        90.00      0.00        NaN            NaN              0.00
# 207680       115.00      0.00        NaN            NaN              0.00
# 204092        18.00      0.00        NaN            NaN              0.00
#
#         serviceCharge        condition interiorQual
# 201             90.00  fully_renovated       normal
# 253681            NaN        well_kept          NaN
# 225352         200.00              NaN          NaN
# 207680         260.00              NaN          NaN
# 204092            NaN      refurbished          NaN

# %%
rentals = rentals[~bad_units3]

# %%
rentals.shape
# Out:
# (266522, 36)

# %%
bad_units4 = (rentals.baseRent == 0) & (rentals.totalRent == 0)
rentals.loc[bad_units4, cols].sort_values(by = 'baseRent_per_sqm').head(50)
# Out:
#         livingSpace  baseRent  totalRent  cf_validation  baseRent_per_sqm  \
# 176365        80.55      0.00       0.00           0.00              0.00
# 69577          0.00      0.00       0.00           0.00               NaN
# 93073          0.00      0.00       0.00           0.00               NaN
#
#         serviceCharge                           condition   interiorQual
# 176365            NaN                      mint_condition            NaN
# 69577            1.50  first_time_use_after_refurbishment  sophisticated
# 93073             NaN                      first_time_use         normal

# %%
rentals = rentals[~bad_units4]
rentals.shape
# Out:
# (266519, 36)

# %%
bad_units5 = ((rentals.baseRent == 0) & (rentals.serviceCharge.notnull())) & (rentals.serviceCharge != 0)
rentals.loc[bad_units5, cols].sort_values(by = 'baseRent_per_sqm')
# Out:
#         livingSpace  baseRent  totalRent  cf_validation  baseRent_per_sqm  \
# 2045          77.00      0.00     731.50            NaN              0.00
# 22673         60.00      0.00     410.00            NaN              0.00
# 55040         47.00      0.00     400.00            NaN              0.00
# 68985         36.00      0.00     410.00            NaN              0.00
# 92860         67.14      0.00     230.00         230.00              0.00
# 102537       115.00      0.00    1050.00            NaN              0.00
# 103052        65.00      0.00     600.00            NaN              0.00
# 127349        59.00      0.00     420.00            NaN              0.00
# 130651        73.00      0.00     700.80            NaN              0.00
# 143557        32.49      0.00     484.00            NaN              0.00
# 144438        53.00      0.00     520.00            NaN              0.00
# 162218        48.50      0.00     120.00         120.00              0.00
# 162875        63.00      0.00     690.00            NaN              0.00
# 179948        30.00      0.00     450.00            NaN              0.00
# 207688        64.00      0.00     425.00            NaN              0.00
# 266925        75.00      0.00     670.00            NaN              0.00
#
#         serviceCharge        condition interiorQual
# 2045           154.00        well_kept          NaN
# 22673          100.00        well_kept          NaN
# 55040           95.00        well_kept       normal
# 68985          100.00              NaN          NaN
# 92860          135.00              NaN          NaN
# 102537         350.00              NaN          NaN
# 103052         200.00              NaN          NaN
# 127349         120.00  fully_renovated          NaN
# 130651         146.00        well_kept          NaN
# 143557          99.00              NaN          NaN
# 144438         150.00              NaN          NaN
# 162218          60.00       negotiable          NaN
# 162875         160.00        well_kept          NaN
# 179948         100.00              NaN       luxury
# 207688         115.00  fully_renovated          NaN
# 266925         170.00        well_kept          NaN

# %%
rentals.loc[bad_units5, ['baseRent']] = rentals.loc[bad_units5, 'totalRent'] - rentals.loc[bad_units5, 'serviceCharge']

# %%
rentals.loc[bad_units5, cols].sort_values(by = 'baseRent_per_sqm')
# Out:
#         livingSpace  baseRent  totalRent  cf_validation  baseRent_per_sqm  \
# 2045          77.00    577.50     731.50            NaN              0.00
# 22673         60.00    310.00     410.00            NaN              0.00
# 55040         47.00    305.00     400.00            NaN              0.00
# 68985         36.00    310.00     410.00            NaN              0.00
# 92860         67.14     95.00     230.00         230.00              0.00
# 102537       115.00    700.00    1050.00            NaN              0.00
# 103052        65.00    400.00     600.00            NaN              0.00
# 127349        59.00    300.00     420.00            NaN              0.00
# 130651        73.00    554.80     700.80            NaN              0.00
# 143557        32.49    385.00     484.00            NaN              0.00
# 144438        53.00    370.00     520.00            NaN              0.00
# 162218        48.50     60.00     120.00         120.00              0.00
# 162875        63.00    530.00     690.00            NaN              0.00
# 179948        30.00    350.00     450.00            NaN              0.00
# 207688        64.00    310.00     425.00            NaN              0.00
# 266925        75.00    500.00     670.00            NaN              0.00
#
#         serviceCharge        condition interiorQual
# 2045           154.00        well_kept          NaN
# 22673          100.00        well_kept          NaN
# 55040           95.00        well_kept       normal
# 68985          100.00              NaN          NaN
# 92860          135.00              NaN          NaN
# 102537         350.00              NaN          NaN
# 103052         200.00              NaN          NaN
# 127349         120.00  fully_renovated          NaN
# 130651         146.00        well_kept          NaN
# 143557          99.00              NaN          NaN
# 144438         150.00              NaN          NaN
# 162218          60.00       negotiable          NaN
# 162875         160.00        well_kept          NaN
# 179948         100.00              NaN       luxury
# 207688         115.00  fully_renovated          NaN
# 266925         170.00        well_kept          NaN

# %%
bad_units6 = (rentals.livingSpace == 0)
rentals.loc[bad_units6, cols].sort_values(by = 'baseRent_per_sqm')
# Out:
#         livingSpace  baseRent  totalRent  cf_validation  baseRent_per_sqm  \
# 3444           0.00    620.00     890.00         890.00               NaN
# 6601           0.00     35.00      35.00          35.00               NaN
# 11127          0.00    775.00     865.00         865.00               NaN
# 15014          0.00    110.00     110.00         110.00               NaN
# 17278          0.00    160.00        NaN            NaN               NaN
# ...             ...       ...        ...            ...               ...
# 247111         0.00    450.00     490.00         490.00               NaN
# 248599         0.00    325.00     465.00         465.00               NaN
# 254055         0.00      0.00     470.00            NaN               NaN
# 266160         0.00    450.00     480.00         480.00               NaN
# 267604         0.00    450.00     490.00         490.00               NaN
#
#         serviceCharge                           condition interiorQual
# 3444           130.00                                 NaN          NaN
# 6601             0.00                           well_kept       normal
# 11127           90.00                           well_kept       normal
# 15014            0.00                                 NaN          NaN
# 17278           69.00                                 NaN          NaN
# ...               ...                                 ...          ...
# 247111          40.00                      mint_condition       normal
# 248599         140.00                           well_kept       normal
# 254055            NaN  first_time_use_after_refurbishment          NaN
# 266160          30.00                                 NaN          NaN
# 267604          40.00                      first_time_use       normal
#
# [66 rows x 8 columns]

# %%
rentals = rentals.loc[~bad_units6]
rentals.shape
# Out:
# (266453, 36)

# %%
bad_units6 = (rentals.totalRent ==  0) 
rentals.loc[bad_units6, cols].sort_values(by = 'baseRent_per_sqm')
# Out:
#         livingSpace  baseRent  totalRent  cf_validation  baseRent_per_sqm  \
# 97475        600.00    340.00       0.00            NaN              0.57
# 35197         77.00    231.00       0.00            NaN              3.00
# 98391         73.00    250.00       0.00            NaN              3.42
# 48701         82.00    285.00       0.00            NaN              3.48
# 5739          63.11    220.50       0.00            NaN              3.49
# ...             ...       ...        ...            ...               ...
# 132091        80.00   1099.00       0.00            NaN             13.74
# 123373        60.00    980.00       0.00            NaN             16.33
# 146770        73.33   1261.00       0.00            NaN             17.20
# 196593        35.00    619.00       0.00            NaN             17.69
# 129810        98.00   2400.00       0.00            NaN             24.49
#
#         serviceCharge                           condition   interiorQual
# 97475             NaN                     fully_renovated            NaN
# 35197           73.00                                 NaN            NaN
# 98391          180.00                                 NaN            NaN
# 48701          180.00                                 NaN            NaN
# 5739            75.00                                 NaN            NaN
# ...               ...                                 ...            ...
# 132091           0.00                      mint_condition         luxury
# 123373           0.00  first_time_use_after_refurbishment  sophisticated
# 146770         238.00                      first_time_use            NaN
# 196593           0.00                           well_kept            NaN
# 129810         290.00  first_time_use_after_refurbishment  sophisticated
#
# [225 rows x 8 columns]

# %%
bad_units7 = (rentals.baseRent == 0) 
rentals.loc[bad_units7, cols].sort_values(by = 'baseRent_per_sqm')
# Out:
#         livingSpace  baseRent  totalRent  cf_validation  baseRent_per_sqm  \
# 1377          30.00      0.00     700.00            NaN              0.00
# 242193        60.00      0.00    1300.00            NaN              0.00
# 237975        57.00      0.00     650.00            NaN              0.00
# 234202        65.00      0.00     600.00            NaN              0.00
# 225417       100.00      0.00     800.00            NaN              0.00
# 225235        45.00      0.00     695.00            NaN              0.00
# 224299        28.00      0.00     325.00            NaN              0.00
# 223839        49.00      0.00     800.00            NaN              0.00
# 206003        43.00      0.00     480.00            NaN              0.00
# 197600        74.00      0.00     650.00            NaN              0.00
# 195524        44.00      0.00    1100.00            NaN              0.00
# 177043        43.00      0.00     390.00            NaN              0.00
# 162978        56.00      0.00     750.00            NaN              0.00
# 150721        75.00      0.00     600.00            NaN              0.00
# 143312        60.00      0.00     550.00            NaN              0.00
# 128598        96.00      0.00     695.00            NaN              0.00
# 118633        62.00      0.00     600.00            NaN              0.00
# 104133        55.00      0.00     500.00            NaN              0.00
# 6911          42.00      0.00     370.00            NaN              0.00
# 19386         22.00      0.00     549.00            NaN              0.00
# 19619         20.00      0.00     470.00            NaN              0.00
# 27784         60.00      0.00     950.00            NaN              0.00
# 34210         18.00      0.00     320.00            NaN              0.00
# 42344         66.15      0.00    1200.00            NaN              0.00
# 246738        17.00      0.00     290.00            NaN              0.00
# 60312         10.00      0.00     220.00            NaN              0.00
# 71567         54.00      0.00     500.00            NaN              0.00
# 77598         65.00      0.00     760.00            NaN              0.00
# 86155         72.00      0.00     890.00            NaN              0.00
# 92070         72.00      0.00     585.00            NaN              0.00
# 93410         45.00      0.00     500.00            NaN              0.00
# 101310        24.00      0.00     330.00            NaN              0.00
# 65775        110.00      0.00      79.00            NaN              0.00
# 264041        30.00      0.00     450.00            NaN              0.00
#
#         serviceCharge        condition   interiorQual
# 1377              NaN  fully_renovated         normal
# 242193           0.00   mint_condition  sophisticated
# 237975            NaN       modernized            NaN
# 234202            NaN              NaN            NaN
# 225417            NaN       modernized            NaN
# 225235           0.00        well_kept         normal
# 224299            NaN        well_kept            NaN
# 223839            NaN  fully_renovated            NaN
# 206003            NaN        well_kept            NaN
# 197600            NaN        well_kept            NaN
# 195524            NaN   mint_condition         luxury
# 177043            NaN        well_kept            NaN
# 162978            NaN        well_kept            NaN
# 150721            NaN              NaN            NaN
# 143312            NaN        well_kept         normal
# 128598            NaN        well_kept            NaN
# 118633            NaN              NaN            NaN
# 104133            NaN              NaN  sophisticated
# 6911              NaN              NaN            NaN
# 19386             NaN              NaN            NaN
# 19619             NaN  fully_renovated         normal
# 27784             NaN  fully_renovated         luxury
# 34210             NaN        well_kept         normal
# 42344             NaN  fully_renovated  sophisticated
# 246738           0.00        well_kept         normal
# 60312             NaN        well_kept         normal
# 71567             NaN              NaN         normal
# 77598             NaN   mint_condition            NaN
# 86155             NaN        well_kept            NaN
# 92070             NaN   mint_condition            NaN
# 93410             NaN  fully_renovated            NaN
# 101310            NaN              NaN            NaN
# 65775             NaN  fully_renovated            NaN
# 264041            NaN              NaN         normal

# %%
rentals.loc[bad_units7, ['baseRent']] = rentals.loc[bad_units7, 'totalRent']

# %%
rentals.loc[bad_units7, cols].sort_values(by = 'baseRent_per_sqm')
# Out:
#         livingSpace  baseRent  totalRent  cf_validation  baseRent_per_sqm  \
# 1377          30.00    700.00     700.00            NaN              0.00
# 242193        60.00   1300.00    1300.00            NaN              0.00
# 237975        57.00    650.00     650.00            NaN              0.00
# 234202        65.00    600.00     600.00            NaN              0.00
# 225417       100.00    800.00     800.00            NaN              0.00
# 225235        45.00    695.00     695.00            NaN              0.00
# 224299        28.00    325.00     325.00            NaN              0.00
# 223839        49.00    800.00     800.00            NaN              0.00
# 206003        43.00    480.00     480.00            NaN              0.00
# 197600        74.00    650.00     650.00            NaN              0.00
# 195524        44.00   1100.00    1100.00            NaN              0.00
# 177043        43.00    390.00     390.00            NaN              0.00
# 162978        56.00    750.00     750.00            NaN              0.00
# 150721        75.00    600.00     600.00            NaN              0.00
# 143312        60.00    550.00     550.00            NaN              0.00
# 128598        96.00    695.00     695.00            NaN              0.00
# 118633        62.00    600.00     600.00            NaN              0.00
# 104133        55.00    500.00     500.00            NaN              0.00
# 6911          42.00    370.00     370.00            NaN              0.00
# 19386         22.00    549.00     549.00            NaN              0.00
# 19619         20.00    470.00     470.00            NaN              0.00
# 27784         60.00    950.00     950.00            NaN              0.00
# 34210         18.00    320.00     320.00            NaN              0.00
# 42344         66.15   1200.00    1200.00            NaN              0.00
# 246738        17.00    290.00     290.00            NaN              0.00
# 60312         10.00    220.00     220.00            NaN              0.00
# 71567         54.00    500.00     500.00            NaN              0.00
# 77598         65.00    760.00     760.00            NaN              0.00
# 86155         72.00    890.00     890.00            NaN              0.00
# 92070         72.00    585.00     585.00            NaN              0.00
# 93410         45.00    500.00     500.00            NaN              0.00
# 101310        24.00    330.00     330.00            NaN              0.00
# 65775        110.00     79.00      79.00            NaN              0.00
# 264041        30.00    450.00     450.00            NaN              0.00
#
#         serviceCharge        condition   interiorQual
# 1377              NaN  fully_renovated         normal
# 242193           0.00   mint_condition  sophisticated
# 237975            NaN       modernized            NaN
# 234202            NaN              NaN            NaN
# 225417            NaN       modernized            NaN
# 225235           0.00        well_kept         normal
# 224299            NaN        well_kept            NaN
# 223839            NaN  fully_renovated            NaN
# 206003            NaN        well_kept            NaN
# 197600            NaN        well_kept            NaN
# 195524            NaN   mint_condition         luxury
# 177043            NaN        well_kept            NaN
# 162978            NaN        well_kept            NaN
# 150721            NaN              NaN            NaN
# 143312            NaN        well_kept         normal
# 128598            NaN        well_kept            NaN
# 118633            NaN              NaN            NaN
# 104133            NaN              NaN  sophisticated
# 6911              NaN              NaN            NaN
# 19386             NaN              NaN            NaN
# 19619             NaN  fully_renovated         normal
# 27784             NaN  fully_renovated         luxury
# 34210             NaN        well_kept         normal
# 42344             NaN  fully_renovated  sophisticated
# 246738           0.00        well_kept         normal
# 60312             NaN        well_kept         normal
# 71567             NaN              NaN         normal
# 77598             NaN   mint_condition            NaN
# 86155             NaN        well_kept            NaN
# 92070             NaN   mint_condition            NaN
# 93410             NaN  fully_renovated            NaN
# 101310            NaN              NaN            NaN
# 65775             NaN  fully_renovated            NaN
# 264041            NaN              NaN         normal

# %%
bad_units8 = (rentals.baseRent_per_sqm < 1) & rentals.totalRent.isnull()
rentals.loc[bad_units8, cols].sort_values(by = 'baseRent_per_sqm')
# Out:
#         livingSpace  baseRent  totalRent  cf_validation  baseRent_per_sqm  \
# 262089       187.70      1.00        NaN            NaN              0.01
# 236543        55.00      1.00        NaN            NaN              0.02
# 220278        40.00      1.00        NaN            NaN              0.03
# 229248      4947.00    200.00        NaN            NaN              0.04
# 30974        300.00     15.00        NaN            NaN              0.05
# 202205      7008.00    519.00        NaN            NaN              0.07
# 215900      2782.00    245.00        NaN            NaN              0.09
# 201135        72.00      8.00        NaN            NaN              0.11
# 222457      2420.00    283.14        NaN            NaN              0.12
# 109023       116.00     14.00        NaN            NaN              0.12
# 208160        60.00     12.50        NaN            NaN              0.21
# 175931        70.00     15.00        NaN            NaN              0.21
# 186853        34.00     12.00        NaN            NaN              0.35
# 92451       2257.88    800.00        NaN            NaN              0.35
# 33817         74.20     35.00        NaN            NaN              0.47
# 15395         74.00     35.00        NaN            NaN              0.47
# 35033          2.00      1.00        NaN            NaN              0.50
# 176653        47.24     25.00        NaN            NaN              0.53
# 143087        85.00     45.00        NaN            NaN              0.53
# 160119        85.00     45.00        NaN            NaN              0.53
# 12614         46.59     25.00        NaN            NaN              0.54
# 152513        70.00     45.00        NaN            NaN              0.64
# 47599         60.00     45.00        NaN            NaN              0.75
# 22823         62.00     57.00        NaN            NaN              0.92
# 257443        70.00     65.00        NaN            NaN              0.93
#
#         serviceCharge                           condition   interiorQual
# 262089            NaN                                 NaN            NaN
# 236543            NaN                          negotiable            NaN
# 220278            NaN                                 NaN            NaN
# 229248         140.00                           well_kept            NaN
# 30974             NaN  first_time_use_after_refurbishment            NaN
# 202205         107.00                           well_kept         normal
# 215900          60.00                     fully_renovated            NaN
# 201135            NaN                      first_time_use            NaN
# 222457          99.35                           well_kept         normal
# 109023            NaN                      first_time_use  sophisticated
# 208160            NaN                                 NaN  sophisticated
# 175931            NaN                           well_kept         normal
# 186853            NaN                          modernized            NaN
# 92451          111.00                                 NaN            NaN
# 33817             NaN                                 NaN            NaN
# 15395             NaN                                 NaN            NaN
# 35033             NaN                                 NaN            NaN
# 176653            NaN                           well_kept  sophisticated
# 143087            NaN                           well_kept         normal
# 160119            NaN                           well_kept         normal
# 12614             NaN                           well_kept  sophisticated
# 152513            NaN                           well_kept            NaN
# 47599             NaN                                 NaN            NaN
# 22823             NaN                      mint_condition  sophisticated
# 257443            NaN                      first_time_use  sophisticated

# %%
rentals = rentals[~bad_units8]
rentals.shape
# Out:
# (266428, 36)

# %%
bad_units9 = (rentals.livingSpace > 900)
rentals.loc[bad_units9, cols].sort_values(by = 'baseRent_per_sqm')
# Out:
#         livingSpace  baseRent  totalRent  cf_validation  baseRent_per_sqm  \
# 175397    111111.00    679.00     369.00            NaN              0.01
# 151184     66100.00   1200.00    1400.00        1400.00              0.02
# 172399      4340.00    200.00     260.00         260.00              0.05
# 51540       8684.00    504.00     650.00         650.00              0.06
# 223187     10259.00   1385.00    1641.50        1641.50              0.14
# 227775      1000.00    539.00     541.50         541.50              0.54
# 243713     14000.00 120000.00        NaN            NaN              8.57
#
#         serviceCharge       condition   interiorQual
# 175397            NaN             NaN            NaN
# 151184         115.00       well_kept  sophisticated
# 172399          60.00       well_kept            NaN
# 51540          146.00      modernized            NaN
# 223187         128.25  mint_condition  sophisticated
# 227775           2.50  first_time_use  sophisticated
# 243713       25000.00       well_kept  sophisticated

# %%
rentals = rentals[~bad_units9]
rentals.shape
# Out:
# (266421, 36)

# %%
bad_units10 = (rentals.baseRent_per_sqm < 1) & (rentals.totalRent > 2 * rentals.baseRent)
rentals.loc[bad_units10, cols].sort_values(by = 'baseRent_per_sqm', ascending = False)
# Out:
#         livingSpace  baseRent  totalRent  cf_validation  baseRent_per_sqm  \
# 31096         48.93     11.20     658.02            NaN              0.23
# 136387        70.00     11.00     720.00            NaN              0.16
# 204024        78.86      9.50     960.00            NaN              0.12
# 170159       100.00     12.00     162.00         162.00              0.12
# 168365        48.39      4.96     326.00            NaN              0.10
# 203671        57.00      5.25     419.00            NaN              0.09
# 194124        58.06      3.01     291.00            NaN              0.05
# 121531       130.00      5.90     767.00            NaN              0.05
# 110217       133.28      6.00     800.00            NaN              0.05
# 113112        80.00      3.00     400.00            NaN              0.04
# 192355       135.00      4.81     784.00            NaN              0.04
# 226354        86.00      3.00     430.00            NaN              0.03
# 9860          92.00      3.00     460.00            NaN              0.03
# 97468         34.00      1.00     121.00         121.00              0.03
# 151820       143.53      3.90     840.00            NaN              0.03
# 92860         67.14     95.00     230.00         230.00              0.00
#
#         serviceCharge                           condition   interiorQual
# 31096          110.00                      first_time_use  sophisticated
# 136387         200.00                      first_time_use  sophisticated
# 204024         105.00                      first_time_use  sophisticated
# 170159         150.00                      first_time_use  sophisticated
# 168365          43.00                      mint_condition            NaN
# 203671          60.00                         refurbished            NaN
# 194124          58.00                         refurbished            NaN
# 121531         190.00                                 NaN  sophisticated
# 110217         150.00                          modernized         normal
# 113112          80.00                         refurbished            NaN
# 192355         134.00  first_time_use_after_refurbishment            NaN
# 226354          86.00                      mint_condition            NaN
# 9860            92.00                         refurbished            NaN
# 97468          120.00                           well_kept         normal
# 151820         140.00                         refurbished            NaN
# 92860          135.00                                 NaN            NaN

# %%
rentals.loc[bad_units10, ['baseRent']] = rentals.loc[bad_units10, 'totalRent']
rentals.loc[bad_units10, ['baseRent_per_sqm']] = rentals.loc[bad_units10, 'baseRent'] / rentals.loc[bad_units10, 'livingSpace']
rentals.loc[bad_units10, cols].sort_values(by = 'baseRent_per_sqm', ascending = False)
# Out:
#         livingSpace  baseRent  totalRent  cf_validation  baseRent_per_sqm  \
# 31096         48.93    658.02     658.02            NaN             13.45
# 204024        78.86    960.00     960.00            NaN             12.17
# 136387        70.00    720.00     720.00            NaN             10.29
# 203671        57.00    419.00     419.00            NaN              7.35
# 168365        48.39    326.00     326.00            NaN              6.74
# 110217       133.28    800.00     800.00            NaN              6.00
# 121531       130.00    767.00     767.00            NaN              5.90
# 151820       143.53    840.00     840.00            NaN              5.85
# 192355       135.00    784.00     784.00            NaN              5.81
# 194124        58.06    291.00     291.00            NaN              5.01
# 9860          92.00    460.00     460.00            NaN              5.00
# 113112        80.00    400.00     400.00            NaN              5.00
# 226354        86.00    430.00     430.00            NaN              5.00
# 97468         34.00    121.00     121.00         121.00              3.56
# 92860         67.14    230.00     230.00         230.00              3.43
# 170159       100.00    162.00     162.00         162.00              1.62
#
#         serviceCharge                           condition   interiorQual
# 31096          110.00                      first_time_use  sophisticated
# 204024         105.00                      first_time_use  sophisticated
# 136387         200.00                      first_time_use  sophisticated
# 203671          60.00                         refurbished            NaN
# 168365          43.00                      mint_condition            NaN
# 110217         150.00                          modernized         normal
# 121531         190.00                                 NaN  sophisticated
# 151820         140.00                         refurbished            NaN
# 192355         134.00  first_time_use_after_refurbishment            NaN
# 194124          58.00                         refurbished            NaN
# 9860            92.00                         refurbished            NaN
# 113112          80.00                         refurbished            NaN
# 226354          86.00                      mint_condition            NaN
# 97468          120.00                           well_kept         normal
# 92860          135.00                                 NaN            NaN
# 170159         150.00                      first_time_use  sophisticated

# %%
bad_units11 = (rentals.baseRent_per_sqm < 1) 
rentals.loc[bad_units11, cols].sort_values(by = 'baseRent_per_sqm', ascending = False)
# Out:
#         livingSpace  baseRent  totalRent  cf_validation  baseRent_per_sqm  \
# 12420        649.00    520.00     720.00         720.00              0.80
# 97475        600.00    340.00       0.00            NaN              0.57
# 114050       115.00     25.00      25.00          25.00              0.22
# 34045         42.57      6.00       7.55           7.55              0.14
# 22609         80.00     10.00      10.00          10.00              0.12
# ...             ...       ...        ...            ...               ...
# 104133        55.00    500.00     500.00            NaN              0.00
# 118633        62.00    600.00     600.00            NaN              0.00
# 127349        59.00    300.00     420.00            NaN              0.00
# 2045          77.00    577.50     731.50            NaN              0.00
# 266925        75.00    500.00     670.00            NaN              0.00
#
#         serviceCharge                           condition   interiorQual
# 12420          200.00  first_time_use_after_refurbishment            NaN
# 97475             NaN                     fully_renovated            NaN
# 114050            NaN                                 NaN            NaN
# 34045            1.55                     fully_renovated  sophisticated
# 22609             NaN                                 NaN            NaN
# ...               ...                                 ...            ...
# 104133            NaN                                 NaN  sophisticated
# 118633            NaN                                 NaN            NaN
# 127349         120.00                     fully_renovated            NaN
# 2045           154.00                           well_kept            NaN
# 266925         170.00                           well_kept            NaN
#
# [63 rows x 8 columns]

# %%
rentals = rentals[~bad_units11]
rentals.shape
# Out:
# (266358, 36)

# %%
rentals['sqm_per_room'] = rentals.livingSpace / rentals.noRooms

# %%
cols2 = ['baseRent', 'serviceCharge','totalRent','noRooms','livingSpace', 'condition',\
        'interiorQual', 'sqm_per_room', 'baseRent_per_sqm']

# %%
bad_units12 = (rentals.sqm_per_room < 8) 
rentals.loc[bad_units12, cols2].sort_values(by = 'sqm_per_room', ascending = False)
# Out:
#         baseRent  serviceCharge  totalRent  noRooms  livingSpace  \
# 63561      50.00            NaN      50.00     1.00         7.70
# 145157    400.00          75.00        NaN     4.00        30.00
# 77676     150.00         130.00        NaN     1.00         7.00
# 67256     277.00          87.00     364.00     5.00        34.60
# 250562    230.00          70.00     300.00     3.00        20.00
# ...          ...            ...        ...      ...          ...
# 18961     395.00           0.00     395.00   140.00        14.00
# 103615    282.00         140.00        NaN   999.99        61.17
# 156291    247.00          58.00        NaN    45.00         2.00
# 163563    400.00         150.00     550.00    30.00         1.00
# 5206     1584.80         228.00    1970.80    99.50         3.00
#
#              condition   interiorQual  sqm_per_room  baseRent_per_sqm
# 63561              NaN            NaN          7.70              6.49
# 145157       well_kept            NaN          7.50             13.33
# 77676              NaN         normal          7.00             21.43
# 67256      refurbished            NaN          6.92              8.01
# 250562       well_kept            NaN          6.67             11.50
# ...                ...            ...           ...               ...
# 18961        well_kept         normal          0.10             28.21
# 103615  first_time_use            NaN          0.06              4.61
# 156291     refurbished            NaN          0.04            123.50
# 163563  first_time_use  sophisticated          0.03            400.00
# 5206    first_time_use  sophisticated          0.03            528.27
#
# [107 rows x 9 columns]

# %%
rentals = rentals[~bad_units12]
rentals.shape
# Out:
# (266251, 37)

# %%
rentals['baseRent_per_room'] = rentals.baseRent / rentals.noRooms
rentals[['baseRent_per_room']]
# Out:
#         baseRent_per_room
# 0                  148.75
# 1                  266.67
# 2                  321.67
# 3                  114.33
# 4                  255.00
# ...                   ...
# 268845             273.33
# 268846             265.71
# 268847             162.50
# 268848             420.00
# 268849             311.67
#
# [266251 rows x 1 columns]

# %%
cols3 = ['baseRent', 'serviceCharge','totalRent','noRooms','livingSpace', 'condition',\
        'interiorQual', 'baseRent_per_room', 'baseRent_per_sqm']
bad_units13 = rentals.baseRent_per_room < 30
rentals.loc[bad_units13, cols3].sort_values(by = 'baseRent_per_room', ascending = False)
# Out:
#         baseRent  serviceCharge  totalRent  noRooms  livingSpace  \
# 211685    450.00          80.00     530.00    16.00       446.00
# 149728     42.00         115.00     535.00     1.50        42.00
# 206309     28.00            NaN      28.00     1.00        12.00
# 11922      25.00            NaN      25.00     1.00        12.50
# 130612     25.00            NaN        NaN     1.00        12.00
# 266668     22.00           0.00        NaN     1.00        15.00
# 82993      15.00           0.00        NaN     1.00        15.00
# 112028    100.00          99.00     199.00     7.00       100.00
#
#                                  condition   interiorQual  baseRent_per_room  \
# 211685  first_time_use_after_refurbishment  sophisticated              28.12
# 149728                          modernized            NaN              28.00
# 206309                           well_kept         normal              28.00
# 11922                       mint_condition            NaN              25.00
# 130612                      mint_condition         normal              25.00
# 266668                          modernized         normal              22.00
# 82993                           modernized         normal              15.00
# 112028                                 NaN         normal              14.29
#
#         baseRent_per_sqm
# 211685              1.01
# 149728              1.00
# 206309              2.33
# 11922               2.00
# 130612              2.08
# 266668              1.47
# 82993               1.00
# 112028              1.00

# %%
rentals = rentals[~bad_units13]

# %% [markdown]
# - Distributions are still right skewed, but there is a bit more spread than the original histograms.

# %% [markdown]
# ### Review Other Numeric Features
# #### 5.6.4 picturecount

# %% [markdown]
# - picturecount indicates how many pictures were loaded to the listing. Min of 0 and max of 121 makes sense.

# %%
_= sns.boxplot(x = 'picturecount', data = rentals)
_= plt.xlabel('Number of Pictures')

# %% [markdown]
# #### 5.6.5 pricetrend

# %% [markdown]
# - pricetrend is a parameter calculated by immoscout. Calculation or metric was not provided, however, it likely indicates the percentage change in price for that apartment or similar apartments in the area. Observed that ~ 0.7% of its values are missing. Has a min value of -12 and max value of 14.9. Range seems reasonable at first glance.

# %%
_= sns.boxplot(x = 'pricetrend', data = rentals)
_= plt.xlabel('pricetrend')

# %% [markdown]
# #### 5.6.6 telekomUploadSpeed

# %% [markdown]
# - telekomUploadSpeed indicates internet upload speed. Determined that 12.4% of its values are missing. Unit not provided, but is typically measured in Mbps. Has seven values, with min speed of 1 and max speed of 100. Range seems reasonable at first glance.

# %%
_= sns.boxplot(x = 'telekomUploadSpeed', data = rentals)
_= plt.xlabel('Mbps')

# %%
rentals.telekomUploadSpeed.value_counts()
# Out:
# 40.00     156759
# 2.40       42450
# 10.00      32591
# 5.00        1019
# 1.00         206
# 100.00       141
# 4.00          63
# Name: telekomUploadSpeed, dtype: int64

# %% [markdown]
# #### 5.6.7 livingSpace

# %% [markdown]
# - livingSpace indicates living space in sqm. Min value of 0 and max value of 110,000 sqm, likely outliers.

# %%
_= sns.boxplot(x = 'livingSpace', data = rentals)
_= plt.xlabel('meters-squared')

# %%
#Determine ideal upper and lower bounds for livingSpace if livingSpace was normally distributed
rentals.livingSpace.describe()
# Out:
# count   266243.00
# mean        73.54
# std         32.04
# min          8.00
# 25%         54.00
# 50%         67.40
# 75%         87.00
# max        601.85
# Name: livingSpace, dtype: float64

# %% [markdown]
# #### 5.6.8 noRooms

# %% [markdown]
# - noRooms indicates number of rooms in apartment. Min value of 1. Max value of 999, likely an outlier.

# %%
_= sns.boxplot(x = 'noRooms', data = rentals)
_= plt.xlabel('Number of Rooms')

# %%
rentals.noRooms.describe()
# Out:
# count   266243.00
# mean         2.63
# std          0.98
# min          1.00
# 25%          2.00
# 50%          3.00
# 75%          3.00
# max         18.00
# Name: noRooms, dtype: float64

# %% [markdown]
# - We notice units having more than 100 rooms.

# %%
#Review distribution
_= rentals.noRooms.hist()
_= plt.xlabel('Number of Rooms')
_= plt.ylabel('Count')

# %% [markdown]
# #### 5.6.9 thermalChar

# %% [markdown]
# - thermalChar indicates energy demand of apartment. Data owner noted that it is used to determine energyEfficiencyClass. Has unit - kWh/(m^2a) [Kilowatt per square meter per annum] Determined that ~ 40% of its values are missing. Has a min value of 0.1 and max value of 1996. Values seem extreme.

# %%
_= sns.boxplot(x = 'thermalChar', data = rentals)
_= plt.xlabel('thermalChar - kWh/(m^2a)')

# %% [markdown]
# - For typical apartment building, thermalChar is between 20 and 120 KWh / (m^2a)

# %%
cols4 = ['baseRent','noRooms','livingSpace', 'condition', \
        'interiorQual', 'firingTypes', 'yearConstructed', 'thermalChar']
rentals.loc[rentals.thermalChar > 1200, cols4].sort_values(by = 'thermalChar', ascending = False)
# Out:
#         baseRent  noRooms  livingSpace                           condition  \
# 71601     650.00     4.00       105.63                                 NaN
# 123270    374.00     2.00        67.00                                 NaN
# 57965     308.00     3.00        61.03                           well_kept
# 217982    800.00     3.00        80.00                           well_kept
# 246864   1200.00     3.00       110.00                      mint_condition
# 122066    265.00     2.00        44.80                                 NaN
# 101444    265.00     2.00        44.80                                 NaN
# 204426    173.00     1.00        35.38                                 NaN
# 262421    173.00     1.00        35.38                                 NaN
# 46204     550.00     3.00        76.00                      mint_condition
# 61428     297.00     2.00        54.00                           well_kept
# 188046    550.00     3.00        79.00                     fully_renovated
# 208006    690.43     1.00        36.83                      mint_condition
# 21686     761.14     1.00        42.58                      mint_condition
# 140927    673.79     1.00        35.79                      mint_condition
# 156511    710.59     1.00        38.09                      mint_condition
# 79145     455.75     1.00        19.70                      mint_condition
# 193561    497.35     1.00        22.64                      mint_condition
# 203638    698.43     1.00        37.33                      mint_condition
# 219167    730.75     1.00        39.35                      mint_condition
# 44774     628.16     1.00        31.94                      mint_condition
# 123641    453.23     1.00        19.56                      mint_condition
# 156876    304.51     2.50        60.65                                 NaN
# 183214    280.59     2.00        47.00                           well_kept
# 122427   1120.00     2.00        60.00                      mint_condition
# 267296    395.00     2.00        59.00                                 NaN
# 65830     600.00     2.00        60.00                     fully_renovated
# 219516    569.15     3.50        60.70  first_time_use_after_refurbishment
# 5898      470.41     2.00        47.00                           well_kept
# 161304    380.00     1.00        11.00                     fully_renovated
# 5412      630.00     1.00        30.00                         refurbished
# 117430    490.00     2.00        90.00                          negotiable
# 81893     520.00     3.00        82.00                                 NaN
# 237292    380.00     2.00        50.00  first_time_use_after_refurbishment
# 207665    521.00     4.00        85.80  first_time_use_after_refurbishment
# 253122    655.00     3.00        79.00                           well_kept
# 30490     380.00     2.00        59.00                     fully_renovated
# 133120    210.00     2.00        43.43                                 NaN
# 256012   1040.00     4.00       114.00                      mint_condition
# 43855     700.00     3.00        86.00                          modernized
# 74762    1260.00     3.00        84.00                           well_kept
# 33309    1050.00     3.00        88.00                                 NaN
# 56902     326.00     3.00        59.30                                 NaN
# 37545     250.00     2.00        52.00                         refurbished
# 76183     780.00     3.00        78.00                                 NaN
# 104409    292.50     3.00        58.50                                 NaN
# 115937    201.60     2.00        44.80                         refurbished
# 148000    155.00     1.00        29.76                                 NaN
# 240794    510.00     3.00        84.00                     fully_renovated
# 221845    542.90     4.00        89.00                           well_kept
# 179135    708.00     6.00       141.52                         refurbished
# 91964     325.00     3.00        68.25                                 NaN
# 87125     330.00     3.00        68.25                                 NaN
# 144760    437.02     3.50        87.00                                 NaN
# 180818    307.71     2.50        61.26                                 NaN
#
#          interiorQual                           firingTypes yearConstructed  \
# 71601             NaN                                   NaN             NaT
# 123270            NaN                      district_heating      1983-01-01
# 57965          normal                      district_heating      1974-01-01
# 217982            NaN                                   gas      1968-01-01
# 246864            NaN                                   NaN      2017-01-01
# 122066            NaN                                   gas             NaT
# 101444            NaN                                   gas             NaT
# 204426         normal                                   gas      1897-01-01
# 262421         normal                                   gas      1897-01-01
# 46204   sophisticated                                   NaN      2018-01-01
# 61428          normal                                   gas      1953-01-01
# 188046         normal                                   oil      1972-01-01
# 208006            NaN                         local_heating      2017-01-01
# 21686             NaN                         local_heating      2017-01-01
# 140927            NaN                         local_heating      2017-01-01
# 156511            NaN                         local_heating      2017-01-01
# 79145             NaN                         local_heating      2017-01-01
# 193561            NaN                         local_heating      2017-01-01
# 203638            NaN                         local_heating      2017-01-01
# 219167            NaN                         local_heating      2017-01-01
# 44774             NaN                         local_heating      2017-01-01
# 123641            NaN                         local_heating      2017-01-01
# 156876            NaN                      district_heating      1998-01-01
# 183214            NaN                                   gas      1967-01-01
# 122427  sophisticated                      district_heating      1963-01-01
# 267296  sophisticated                                   gas      1998-01-01
# 65830             NaN                                   gas             NaT
# 219516  sophisticated                                   oil      1963-01-01
# 5898           normal                                   oil      1963-01-01
# 161304  sophisticated                                   gas             NaT
# 5412           normal                                   oil      1952-01-01
# 117430         normal                                   gas      1955-01-01
# 81893             NaN  combined_heat_and_power_fossil_fuels      1908-01-01
# 237292         normal                                   gas             NaT
# 207665  sophisticated                      district_heating      1969-01-01
# 253122         normal                                   gas      1928-01-01
# 30490             NaN                     natural_gas_light      2000-01-01
# 133120            NaN                                   NaN      1996-01-01
# 256012  sophisticated                                   gas      2007-01-01
# 43855          normal                                   gas      1994-01-01
# 74762          normal                      district_heating      1973-01-01
# 33309          normal                     natural_gas_light      1954-01-01
# 56902             NaN                                   NaN      1961-01-01
# 37545   sophisticated                                   gas      1957-01-01
# 76183             NaN                                   gas      1999-01-01
# 104409            NaN                                   NaN      1961-01-01
# 115937            NaN                                   NaN             NaT
# 148000            NaN                                   NaN      1979-01-01
# 240794         normal                     natural_gas_light      1959-01-01
# 221845         normal                                   gas      1996-01-01
# 179135  sophisticated                        pellet_heating      1900-01-01
# 91964             NaN                                   NaN      1957-01-01
# 87125             NaN                                   NaN      1957-01-01
# 144760            NaN                      district_heating      2001-01-01
# 180818            NaN                      district_heating      2001-01-01
#
#         thermalChar
# 71601       1996.00
# 123270      1983.00
# 57965       1974.00
# 217982      1971.00
# 246864      1932.00
# 122066      1900.00
# 101444      1900.00
# 204426      1897.00
# 262421      1897.00
# 46204       1890.00
# 61428       1752.00
# 188046      1745.00
# 208006      1717.90
# 21686       1717.90
# 140927      1717.90
# 156511      1717.90
# 79145       1717.90
# 193561      1717.90
# 203638      1717.90
# 219167      1717.90
# 44774       1717.90
# 123641      1717.90
# 156876      1653.00
# 183214      1649.00
# 122427      1613.00
# 267296      1563.20
# 65830       1555.00
# 219516      1546.00
# 5898        1546.00
# 161304      1535.00
# 5412        1524.00
# 117430      1509.00
# 81893       1501.00
# 237292      1500.00
# 207665      1484.00
# 253122      1477.00
# 30490       1423.00
# 133120      1413.00
# 256012      1394.00
# 43855       1363.00
# 74762       1360.00
# 33309       1347.00
# 56902       1347.00
# 37545       1342.00
# 76183       1335.00
# 104409      1322.00
# 115937      1307.00
# 148000      1269.00
# 240794      1254.00
# 221845      1246.00
# 179135      1236.60
# 91964       1219.00
# 87125       1219.00
# 144760      1209.00
# 180818      1209.00

# %% [markdown]
# - 123270 and 57965 are dates. We will remove these rows

# %%
rentals = rentals.loc[~rentals.index.isin([123270, 57965])]

# %%
rentals.loc[rentals.thermalChar < 1, cols4].sort_values(by = 'thermalChar')
# Out:
#         baseRent  noRooms  livingSpace                           condition  \
# 21962     624.00     3.00        78.00                           well_kept
# 57693     695.00     2.00        46.23                      first_time_use
# 53510    1195.00     3.00       105.78                      first_time_use
# 47158    1195.00     3.00       105.78                      first_time_use
# 125961   1195.00     3.00       105.78                      first_time_use
# 127217   1590.00     3.00        92.00  first_time_use_after_refurbishment
# 156348    764.64     2.00        70.80                      first_time_use
# 228995    360.00     2.50        55.00                          modernized
# 31114    1195.00     3.00        61.30                      first_time_use
# 30229    1050.00     2.00        50.80                      first_time_use
# 110169   1195.00     3.00        61.30                      first_time_use
# 139793   1495.00     3.00       103.94                      first_time_use
# 143579   1195.00     3.00        61.30                      first_time_use
# 35698    1195.00     3.00        61.30                      first_time_use
# 204836    370.00     2.00        59.00                                 NaN
# 138846   1150.63     3.00        92.05                      mint_condition
# 243108   1340.00     7.00       186.21                      mint_condition
# 90142     530.00     2.00        69.00                         refurbished
# 201412    695.00     3.00       117.61                     fully_renovated
#
#          interiorQual        firingTypes yearConstructed  thermalChar
# 21962             NaN                oil      1968-01-01         0.10
# 57693   sophisticated  natural_gas_light      2018-01-01         0.20
# 53510             NaN                gas      2019-01-01         0.20
# 47158          luxury                gas      2019-01-01         0.20
# 125961         luxury                gas      2019-01-01         0.20
# 127217  sophisticated          coal_coke      2019-01-01         0.25
# 156348  sophisticated   district_heating      2017-01-01         0.27
# 228995  sophisticated                gas      1965-01-01         0.28
# 31114   sophisticated                gas      2017-01-01         0.30
# 30229   sophisticated                gas      2017-01-01         0.30
# 110169  sophisticated                gas      2017-01-01         0.30
# 139793         luxury                gas      2017-01-01         0.30
# 143579  sophisticated                gas      2017-01-01         0.30
# 35698   sophisticated                gas      2017-01-01         0.30
# 204836         normal                gas             NaT         0.39
# 138846         luxury                gas      2014-01-01         0.46
# 243108  sophisticated                gas      2014-01-01         0.49
# 90142             NaN                gas      1986-01-01         0.64
# 201412         normal                oil      1890-01-01         0.71

# %% [markdown]
# - thermalChar has low values for mostly apartments that have had some work done to them (e.g. first_time_use, full_renovated, etc.)

# %% [markdown]
# #### 5.6.10 floor and numberOfFloors

# %% [markdown]
# - floor indicates floor number of apartment. Determined that 19% of its values are missing. Has 53 unique values, with min of -1 and max of 999. Min of -1 likely indicates a basement apartment, but a max of 999 is an extreme value. Floor number is an identifier for the apartment specific to the building.
# - numberOfFloors indicates the number of floors in the building. Has 57 unique values, with min of 0 and max of 999, similar to 'floor'. 999 is an extreme values.

# %%
fig, ax = plt.subplots(nrows = 1,ncols = 2, figsize=(15, 5))
_= sns.boxplot(x = 'floor', data = rentals, ax = ax[0])
_= sns.boxplot(x = 'numberOfFloors', data = rentals, ax = ax[1])
plt.subplots_adjust(wspace= 0.5)
plt.show()

# %% [markdown]
# - Tallest German building has 56 floors. We will filter with this limit. Also we note that the numberOfFloors provides a relates better to price than the number of the floor. We will drop floor.

# %%
#Drop floor
rentals.drop('floor', axis =1, inplace = True)

# %%
#Remove outliers in numberOfFloors
cols5 = ['baseRent','noRooms','livingSpace', 'condition', \
        'interiorQual', 'yearConstructed', 'typeOfFlat', 'numberOfFloors', 'totalRent']
rentals.loc[(rentals.numberOfFloors > 56), cols5]
# Out:
#         baseRent  noRooms  livingSpace        condition   interiorQual  \
# 26590     570.00     1.50        40.00        well_kept            NaN
# 35220     245.00     1.50        44.20        well_kept         normal
# 43275     378.00     2.00        61.00  fully_renovated         normal
# 48498     600.00     2.00        50.00   mint_condition  sophisticated
# 64453     500.00     2.50        92.00        well_kept         normal
# 72253     680.00     2.00        69.00   mint_condition  sophisticated
# 82112     280.00     1.00        52.50        well_kept            NaN
# 100789    300.00     1.00        27.00        well_kept         normal
# 107377    560.00     2.00        75.00              NaN            NaN
# 123333    399.00     2.00        73.00        well_kept         normal
# 150943    600.00     3.00        70.00        well_kept  sophisticated
# 152273   1280.00     5.00       150.00  fully_renovated  sophisticated
# 181497    450.00     3.00        73.00        well_kept         normal
# 202923    410.00     2.00        74.00              NaN            NaN
# 244899    338.00     3.00        75.00        well_kept            NaN
# 247865    494.00     2.00        52.00       negotiable  sophisticated
# 251964    680.00     2.50        62.40              NaN  sophisticated
# 262400    660.00     2.00        66.00      refurbished  sophisticated
# 264425    424.00     2.00        46.39        well_kept         normal
#
#        yearConstructed           typeOfFlat  numberOfFloors  totalRent
# 26590              NaT          roof_storey           90.00        NaN
# 35220              NaT                other          301.00       2.00
# 43275       1935-01-01            apartment          378.00     512.00
# 48498       1976-01-01            apartment          999.00     720.00
# 64453       1982-01-01  raised_ground_floor           92.00     620.00
# 72253       1985-01-01         ground_floor          999.00     850.00
# 82112       1995-01-01            apartment          400.00       4.00
# 100789      1973-01-01                other          999.00        NaN
# 107377             NaT          roof_storey          800.00     680.00
# 123333      1954-01-01            apartment          594.00        NaN
# 150943      1970-01-01            apartment          600.00        NaN
# 152273      1986-01-01  raised_ground_floor          370.00    1740.00
# 181497      2000-01-01          roof_storey          800.00     590.00
# 202923             NaT          roof_storey          410.00     540.00
# 244899      1961-01-01            apartment           99.00     478.00
# 247865      1996-01-01            apartment           99.00     632.00
# 251964      1990-01-01            apartment          200.00     810.00
# 262400      1955-01-01            apartment          730.00     908.00
# 264425             NaT            apartment          252.00     529.00

# %% [markdown]
# - We will remove numberOfFloors > 56

# %%
rentals = rentals.loc[~(rentals.numberOfFloors > 56)]

# %%
rentals.shape
# Out:
# (266222, 37)

# %%
#Review distribution
_= rentals.numberOfFloors.hist()
_= plt.xlabel('Number of Floors')
_= plt.ylabel('Count')

# %% [markdown]
# ## 5.7 Review of Boolean Features

# %%
rentals.select_dtypes('boolean').head()
# Out:
#    newlyConst  balcony  hasKitchen  cellar   lift  garden
# 0       False    False       False    True  False    True
# 1       False     True       False   False  False   False
# 2        True     True       False    True   True   False
# 3       False     True       False   False  False   False
# 4       False     True       False   False  False   False

# %%
#Review missing values
rentals.select_dtypes('boolean').isna().sum()
# Out:
# newlyConst    0
# balcony       0
# hasKitchen    0
# cellar        0
# lift          0
# garden        0
# dtype: int64

# %% [markdown]
# ## 5.8 Review Datatime Features

# %%
rentals.select_dtypes('datetime').head()
# Out:
#   yearConstructed       date
# 0      1965-01-01 2019-05-01
# 1      1871-01-01 2019-05-01
# 2      2019-01-01 2019-10-01
# 3      1964-01-01 2019-05-01
# 4      1950-01-01 2020-02-01

# %% [markdown]
# ### 5.8.1 yearConstructed

# %%
#Plot distribution
_ = rentals.yearConstructed.dt.year.hist()
_= plt.xlabel('yearConstructed')
_= plt.ylabel('Count')

# %% [markdown]
# - There are dates past 2020

# %%
rentals.loc[rentals.yearConstructed.dt.year >= 2026, ['state','date','baseRent', 'yearConstructed', 'condition', 'interiorQual']]
# Out:
#                     state       date  baseRent yearConstructed  \
# 40265              Berlin 2020-02-01    470.00      2029-01-01
# 54595              Hessen 2019-10-01   2945.00      2026-01-01
# 87221   Baden_Württemberg 2019-05-01   1175.00      2090-01-01
# 182121             Hessen 2019-10-01   1620.00      2026-01-01
# 240346             Hessen 2019-10-01   1435.00      2026-01-01
#
#              condition   interiorQual
# 40265   first_time_use  sophisticated
# 54595   mint_condition            NaN
# 87221   mint_condition            NaN
# 182121  mint_condition            NaN
# 240346  mint_condition            NaN

# %% [markdown]
# - We observe than many of the units are first-time use. We will remove rows for values in 2029 and 2090 because the are too far out.

# %%
#Filter-out outliers
rentals = rentals[~rentals.index.isin([40265, 87221])]
rentals[rentals.yearConstructed.dt.year > 2026]
# Out:
# Empty DataFrame
# Columns: [state, serviceCharge, heatingType, telekomTvOffer, newlyConst, balcony, picturecount, pricetrend, telekomUploadSpeed, totalRent, yearConstructed, scoutId, firingTypes, hasKitchen, cellar, baseRent, livingSpace, condition, interiorQual, petsAllowed, lift, typeOfFlat, zip_code, noRooms, thermalChar, numberOfFloors, garden, district, town_municipality, date, crossfield_service, cf_validation, baseRent_per_sqm, totalRent_per_sqm, wrong_addition, sqm_per_room, baseRent_per_room]
# Index: []

# %%
rentals.shape
# Out:
# (266220, 37)

# %% [markdown]
# ## 5.9 State-wide Features

# %% [markdown]
# ### 5.9.2 State Profile

# %%
#Load German states information
states_url = 'https://en.wikipedia.org/wiki/States_of_Germany'
german_states = pd.read_html(states_url)

# %%
states = german_states[5]
states
# Out:
#     Coat of arms  Flag                                        State     Since  \
# 0            NaN   NaN                            Baden-Württemberg  1952[10]
# 1            NaN   NaN                              Bavaria(Bayern)      1949
# 2            NaN   NaN                                       Berlin  1990[11]
# 3            NaN   NaN                                  Brandenburg      1990
# 4            NaN   NaN                                       Bremen      1949
# 5            NaN   NaN                                      Hamburg      1949
# 6            NaN   NaN                                Hesse(Hessen)      1949
# 7            NaN   NaN                  Lower Saxony(Niedersachsen)      1949
# 8            NaN   NaN                       Mecklenburg-Vorpommern      1990
# 9            NaN   NaN  North Rhine-Westphalia(Nordrhein-Westfalen)      1949
# 10           NaN   NaN        Rhineland-Palatinate(Rheinland-Pfalz)      1949
# 11           NaN   NaN                                     Saarland      1957
# 12           NaN   NaN                              Saxony(Sachsen)      1990
# 13           NaN   NaN                Saxony-Anhalt(Sachsen-Anhalt)      1990
# 14           NaN   NaN                           Schleswig-Holstein      1949
# 15           NaN   NaN                         Thuringia(Thüringen)      1990
#
#               Capital                        Legislature  \
# 0           Stuttgart       Landtag of Baden-Württemberg
# 1     Munich(München)                 Landtag of Bavaria
# 2                   –                   Abgeordnetenhaus
# 3             Potsdam             Landtag of Brandenburg
# 4              Bremen             Bürgerschaft of Bremen
# 5                   –            Bürgerschaft of Hamburg
# 6           Wiesbaden                   Landtag of Hesse
# 7   Hanover(Hannover)            Landtag of Lower Saxony
# 8            Schwerin  Landtag of Mecklenburg-Vorpommern
# 9          Düsseldorf  Landtag of North Rhine-Westphalia
# 10              Mainz    Landtag of Rhineland-Palatinate
# 11        Saarbrücken                Landtag of Saarland
# 12            Dresden                  Landtag of Saxony
# 13          Magdeburg           Landtag of Saxony-Anhalt
# 14               Kiel      Landtag of Schleswig-Holstein
# 15             Erfurt               Landtag of Thuringia
#
#                Head of government    Governmentcoalition  Bundesrat votes  \
# 0   Winfried Kretschmann (Greens)            Greens, CDU                6
# 1              Markus Söder (CSU)                CSU, FW                6
# 2            Michael Müller (SPD)  SPD, The Left, Greens                4
# 3            Dietmar Woidke (SPD)       SPD, CDU, Greens                4
# 4      Andreas Bovenschulte (SPD)  SPD, Greens, The Left                3
# 5        Peter Tschentscher (SPD)            SPD, Greens                3
# 6           Volker Bouffier (CDU)            CDU, Greens                5
# 7              Stephan Weil (SPD)               SPD, CDU                6
# 8          Manuela Schwesig (SPD)               SPD, CDU                3
# 9             Armin Laschet (CDU)               CDU, FDP                6
# 10              Malu Dreyer (SPD)       SPD, FDP, Greens                4
# 11              Tobias Hans (CDU)               CDU, SPD                3
# 12       Michael Kretschmer (CDU)       CDU, Greens, SPD                4
# 13          Reiner Haseloff (CDU)       CDU, SPD, Greens                4
# 14           Daniel Günther (CDU)       CDU, Greens, FDP                4
# 15        Bodo Ramelow (The Left)  The Left, SPD, Greens                4
#
#     Area(km2)  Population(Dec. 2019)[7]  Pop.per km2  HDI(2018)[8]  \
# 0       35752                  11100394          310          0.95
# 1       70552                  13124737          185          0.95
# 2         892                   3669491         4086          0.95
# 3       29479                   2521893           85          0.91
# 4         419                    681202         1630          0.95
# 5         755                   1847253         2439          0.97
# 6       21115                   6288080          297          0.95
# 7       47609                   7993448          168          0.92
# 8       23180                   1609675           69          0.91
# 9       34085                  17932651          526          0.94
# 10      19853                   4084844          206          0.93
# 11       2569                    990509          386          0.93
# 12      18416                   4077937          221          0.93
# 13      20446                   2208321          108          0.91
# 14      15799                   2896712          183          0.92
# 15      16172                   2143145          133          0.92
#
#    ISO3166-2code  GDP per capita in Euro (2018)[9]
# 0             BW                             47290
# 1             BY                             48323
# 2             BE                             41967
# 3             BB                             29541
# 4             HB                             49215
# 5             HH                             66879
# 6             HE                             46923
# 7             NI                             38423
# 8             MV                             28940
# 9             NW                             39678
# 10            RP                             35457
# 11            SL                             36684
# 12            SN                             31453
# 13            ST                             28800
# 14            SH                             33712
# 15            TH                             29883

# %%
state_features = states[['State', 'Area(km2)', 'Population(Dec. 2019)[7]', 'Pop.per km2', 'GDP per capita in Euro (2018)[9]', 'HDI(2018)[8]']]
state_features.head()
# Out:
#                State  Area(km2)  Population(Dec. 2019)[7]  Pop.per km2  \
# 0  Baden-Württemberg      35752                  11100394          310
# 1    Bavaria(Bayern)      70552                  13124737          185
# 2             Berlin        892                   3669491         4086
# 3        Brandenburg      29479                   2521893           85
# 4             Bremen        419                    681202         1630
#
#    GDP per capita in Euro (2018)[9]  HDI(2018)[8]
# 0                             47290          0.95
# 1                             48323          0.95
# 2                             41967          0.95
# 3                             29541          0.91
# 4                             49215          0.95

# %%
state_features.columns = ['State', 'area_km2', 'population_2019', 'population_per_km2', 'gdp_per_capita_2018', 'hdi']
state_features.head()
# Out:
#                State  area_km2  population_2019  population_per_km2  \
# 0  Baden-Württemberg     35752         11100394                 310
# 1    Bavaria(Bayern)     70552         13124737                 185
# 2             Berlin       892          3669491                4086
# 3        Brandenburg     29479          2521893                  85
# 4             Bremen       419           681202                1630
#
#    gdp_per_capita_2018  hdi
# 0                47290 0.95
# 1                48323 0.95
# 2                41967 0.95
# 3                29541 0.91
# 4                49215 0.95

# %%
rentals.shape
# Out:
# (266220, 37)

# %% [markdown]
# ## 5.10 Target feature

# %% [markdown]
# - We need to choose between totalRent and baseRent for our modelling.

# %%
#Review relationship between baseRent and totalRent
_= sns.scatterplot(x = 'totalRent', y = 'baseRent', data = rentals)
_= plt.xlabel('Total Rent (euros)')
_= plt.ylabel('Base Rent (euros)')

# %%
#Count missing values of totalRent and baseRent
rentals.totalRent.isnull().sum(), rentals.baseRent.isnull().sum()
# Out:
# (40055, 0)

# %% [markdown]
# - We note that thare are over 40,000 missing values for totalRent and 0 missing values for baseRent.
# - We note that totalRent is composed of baseRent and other features.
# - We will therefore use baseRent as our target feature and drop totalRent

# %%
#Recalculating parameters
rentals.baseRent_per_sqm = rentals.baseRent / rentals.livingSpace

# %%
rentals.columns
# Out:
# Index(['state', 'serviceCharge', 'heatingType', 'telekomTvOffer', 'newlyConst',
#        'balcony', 'picturecount', 'pricetrend', 'telekomUploadSpeed',
#        'totalRent', 'yearConstructed', 'scoutId', 'firingTypes', 'hasKitchen',
#        'cellar', 'baseRent', 'livingSpace', 'condition', 'interiorQual',
#        'petsAllowed', 'lift', 'typeOfFlat', 'zip_code', 'noRooms',
#        'thermalChar', 'numberOfFloors', 'garden', 'district',
#        'town_municipality', 'date', 'crossfield_service', 'cf_validation',
#        'baseRent_per_sqm', 'totalRent_per_sqm', 'wrong_addition',
#        'sqm_per_room', 'baseRent_per_room'],
#       dtype='object')

# %%
rentals.groupby('state')['zip_code'].count()
# Out:
# state
# Baden_Württemberg         15961
# Bayern                    21490
# Berlin                    10271
# Brandenburg                6875
# Bremen                     2940
# Hamburg                    3730
# Hessen                    17682
# Mecklenburg_Vorpommern     6580
# Niedersachsen             16404
# Nordrhein_Westfalen       62069
# Rheinland_Pfalz            8324
# Saarland                   1411
# Sachsen                   57673
# Sachsen_Anhalt            19909
# Schleswig_Holstein         6603
# Thüringen                  8298
# Name: zip_code, dtype: int64

# %%
berlin = rentals.loc[rentals.state == 'Berlin', :]

# %%
set(berlin.state.values)
# Out:
# {'Berlin'}

# %%
berlin.groupby('zip_code')['zip_code'].count()
# Out:
# zip_code
# 10017      1
# 10115    263
# 10117    226
# 10119     74
# 10171      6
#         ...
# 14193    107
# 14195     66
# 14197     20
# 14199     70
# 19437      1
# Name: zip_code, Length: 214, dtype: int64

# %%
berlin.loc[berlin.zip_code == 14199, ['baseRent', 'noRooms', 'town_municipality', 'district']]
# Out:
#         baseRent  noRooms          town_municipality district
# 556      1247.70     4.50  Schmargendorf_Wilmersdorf   Berlin
# 6542     1659.00     2.00  Schmargendorf_Wilmersdorf   Berlin
# 6925     1250.00     3.00  Schmargendorf_Wilmersdorf   Berlin
# 7001     1420.00     3.50  Schmargendorf_Wilmersdorf   Berlin
# 8761      645.00     1.50  Schmargendorf_Wilmersdorf   Berlin
# ...          ...      ...                        ...      ...
# 245580   1973.30     3.50  Schmargendorf_Wilmersdorf   Berlin
# 246224   1848.00     4.00  Schmargendorf_Wilmersdorf   Berlin
# 256972   2363.00     5.00  Schmargendorf_Wilmersdorf   Berlin
# 260828   1640.00     2.00  Schmargendorf_Wilmersdorf   Berlin
# 265778    530.00     1.00  Schmargendorf_Wilmersdorf   Berlin
#
# [70 rows x 4 columns]

# %%
set(berlin.town_municipality)
# Out:
# {'Adlershof_Treptow',
#  'Alt_Hohenschönhausen_Hohenschönhausen',
#  'Altglienicke_Treptow',
#  'Baumschulenweg_Treptow',
#  'Biesdorf_Marzahn',
#  'Blankenburg_Weißensee',
#  'Bohnsdorf_Treptow',
#  'Britz_Neukölln',
#  'Buch_Pankow',
#  'Buckow_Neukölln',
#  'Charlottenburg_Charlottenburg',
#  'Dahlem_Zehlendorf',
#  'Falkenberg_Hohenschönhausen',
#  'Französisch_Buchholz_Pankow',
#  'Friedenau_Schöneberg',
#  'Friedrichsfelde_Lichtenberg',
#  'Friedrichshagen_Köpenick',
#  'Friedrichshain_Friedrichshain',
#  'Frohnau_Reinickendorf',
#  'Gatow_Spandau',
#  'Grunewald_Wilmersdorf',
#  'Grünau_Köpenick',
#  'Haselhorst_Spandau',
#  'Heiligensee_Reinickendorf',
#  'Heinersdorf_Weißensee',
#  'Hellersdorf_Hellersdorf',
#  'Hermsdorf_Reinickendorf',
#  'Johannisthal_Treptow',
#  'Karlshorst_Lichtenberg',
#  'Karow_Weißensee',
#  'Kaulsdorf_Hellersdorf',
#  'Kladow_Spandau',
#  'Konradshöhe_Reinickendorf',
#  'Kreuzberg_Kreuzberg',
#  'Köpenick_Köpenick',
#  'Lankwitz_Steglitz',
#  'Lichtenberg_Lichtenberg',
#  'Lichtenrade_Tempelhof',
#  'Lichterfelde_Steglitz',
#  'Lübars_Reinickendorf',
#  'Mahlsdorf_Hellersdorf',
#  'Malchow_Hohenschönhausen',
#  'Mariendorf_Tempelhof',
#  'Marienfelde_Tempelhof',
#  'Marzahn_Marzahn',
#  'Mitte_Mitte',
#  'Müggelheim_Köpenick',
#  'Neu_Hohenschönhausen_Hohenschönhausen',
#  'Neukölln_Neukölln',
#  'Niederschöneweide_Treptow',
#  'Niederschönhausen_Pankow',
#  'Nikolassee_Zehlendorf',
#  'Oberschöneweide_Köpenick',
#  'Pankow_Pankow',
#  'Plänterwald_Treptow',
#  'Prenzlauer_Berg_Prenzlauer_Berg',
#  'Rahnsdorf_Köpenick',
#  'Reinickendorf_Reinickendorf',
#  'Rosenthal_Pankow',
#  'Rudow_Neukölln',
#  'Rummelsburg_Lichtenberg',
#  'Schmargendorf_Wilmersdorf',
#  'Schmöckwitz_Köpenick',
#  'Schöneberg_Schöneberg',
#  'Siemensstadt_Spandau',
#  'Spandau_Spandau',
#  'Staaken_Spandau',
#  'Steglitz_Steglitz',
#  'Tegel_Reinickendorf',
#  'Tempelhof_Tempelhof',
#  'Tiergarten_Tiergarten',
#  'Treptow_Treptow',
#  'Waidmannslust_Reinickendorf',
#  'Wannsee_Zehlendorf',
#  'Wedding_Wedding',
#  'Weißensee_Weißensee',
#  'Wilmersdorf_Wilmersdorf',
#  'Wittenau_Reinickendorf',
#  'Zehlendorf_Zehlendorf'}

# %%
#Dropping unwanted columns
rentals.drop(columns = ['totalRent', 'crossfield_service', 'cf_validation', 'totalRent_per_sqm', \
                        'wrong_addition', 'sqm_per_room', 'baseRent_per_room', 'picturecount', 'pricetrend',\
                       'scoutId', 'zip_code', 'town_municipality', 'district'], inplace = True)

# %%
rentals = rentals.rename(columns = {'baseRent': 'rent', 'baseRent_per_sqm': 'rent_per_sqm'})

# %%
rentals.shape
# Out:
# (266220, 24)

# %% [markdown]
# # 6. Summary

# %% [markdown]
# - We started with a dataframe of 268,850 rows and 49 columns
# - We concluded with a dataframe of 266,568 rows and 29 columns
# - We removed columns that had over 40% of their values missing
# - We removed duplicated rows
# - We removed redundant columns that had high cardinality and offered no clear benefits
# - We removed columns that were aggregrate values of other columns. These were columns with binned data derived from other columns
# - We removed rows with missing rent information
# - We removed rows with outlier values for particular numerical features
# - We imported data associated with state-wise features
# - Finally, we chose the baseRent feature as our target feature.

# %% [markdown]
# # 7. Saving New Dataframes

# %%
datapath = '..\data\processed'
if not os.path.exists(datapath):
    os.mkdir(datapath)

# %%
datapath_rentals = os.path.join(datapath, 'rentals_cleaned.csv')
if not os.path.exists(datapath_rentals):
    rentals.to_csv(datapath_rentals, index=False)

# %%
datapath_state_features = os.path.join(datapath, 'state_features.csv')
if not os.path.exists(datapath_state_features):
    state_features.to_csv(datapath_state_features, index=False)
